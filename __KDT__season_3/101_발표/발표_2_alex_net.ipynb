# %% [markdown]
# ### Alex Net
#
# - 객체 인식
# - 르넷보다 더큰 데이터 셋 (대규모 딥 컨볼루션 신경망)
# - 120만개의 고해상도 클래스를 1000개로
#
# - 더좋은 성능
#
# ### 구조
# - 컨볼루션 5
# - 완전 3
# - 1000 WAY 소프트 맥스

# %% [markdown]
# - 22000 개의 이미지넷, 1500 만개의 라벨 붙은 고해상도 이미지

# %% [markdown]
# - 렐루 이용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
