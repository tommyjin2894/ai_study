# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from glob import glob

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats("png2x") # svg, retina, png2x ...
mpl.style.use("seaborn-v0_8")
mpl.rcParams.update({"figure.constrained_layout.use": True})
sns.set_context("paper") 
sns.set_palette("Set2") 
sns.set_style("whitegrid") 

plt.rc("font", family = "DejaVu Sans")
plt.rcParams["axes.unicode_minus"] = False

# %%
def load_images_and_labels(files, label, size):
    images = [image.load_img(p, target_size=(size, size)) for p in files]  # warping
    labels = [label] * len(files)
    print(files)
    return images, labels

# %%
man_file= glob('../data/imgs/data_mw/man/*jpg')
wom_file= glob('../data/imgs/data_mw/woman/*jpg')

man_file_224_x, man_file_224_y = load_images_and_labels(man_file, 0, 224)
wom_file_224_x, wom_file_224_y = load_images_and_labels(wom_file, 1, 224)

from tensorflow.keras.utils import to_categorical

images_224 = man_file_224_x + wom_file_224_x
labels = man_file_224_y + wom_file_224_y
labels = to_categorical(labels)
vector_224 = np.asarray([image.img_to_array(img) for img in images_224])

x_train, x_test, y_train, y_test = train_test_split(vector_224, labels, random_state=42, test_size=0.2)
# Out:
# ['../data/imgs/data_mw/man/ma_194.jpg', '../data/imgs/data_mw/man/ma_44.jpg', '../data/imgs/data_mw/man/ma_117.jpg', '../data/imgs/data_mw/man/ma_77.jpg', '../data/imgs/data_mw/man/ma_165.jpg', '../data/imgs/data_mw/man/ma_163.jpg', '../data/imgs/data_mw/man/ma_119.jpg', '../data/imgs/data_mw/man/ma_26.jpg', '../data/imgs/data_mw/man/ma_50.jpg', '../data/imgs/data_mw/man/ma_144.jpg', '../data/imgs/data_mw/man/ma_99.jpg', '../data/imgs/data_mw/man/ma_19.jpg', '../data/imgs/data_mw/man/ma_9.jpg', '../data/imgs/data_mw/man/ma_147.jpg', '../data/imgs/data_mw/man/ma_171.jpg', '../data/imgs/data_mw/man/ma_88.jpg', '../data/imgs/data_mw/man/ma_94.jpg', '../data/imgs/data_mw/man/ma_100.jpg', '../data/imgs/data_mw/man/ma_8.jpg', '../data/imgs/data_mw/man/ma_71.jpg', '../data/imgs/data_mw/man/ma_55.jpg', '../data/imgs/data_mw/man/ma_49.jpg', '../data/imgs/data_mw/man/ma_39.jpg', '../data/imgs/data_mw/man/ma_157.jpg', '../data/imgs/data_mw/man/ma_60.jpg', '../data/imgs/data_mw/man/ma_185.jpg', '../data/imgs/data_mw/man/ma_191.jpg', '../data/imgs/data_mw/man/ma_12.jpg', '../data/imgs/data_mw/man/ma_42.jpg', '../data/imgs/data_mw/man/ma_22.jpg', '../data/imgs/data_mw/man/ma_110.jpg', '../data/imgs/data_mw/man/ma_127.jpg', '../data/imgs/data_mw/man/ma_151.jpg', '../data/imgs/data_mw/man/ma_146.jpg', '../data/imgs/data_mw/man/ma_93.jpg', '../data/imgs/data_mw/man/ma_78.jpg', '../data/imgs/data_mw/man/ma_161.jpg', '../data/imgs/data_mw/man/ma_138.jpg', '../data/imgs/data_mw/man/ma_139.jpg', '../data/imgs/data_mw/man/ma_89.jpg', '../data/imgs/data_mw/man/ma_74.jpg', '../data/imgs/data_mw/man/ma_51.jpg', '../data/imgs/data_mw/man/ma_36.jpg', '../data/imgs/data_mw/man/ma_159.jpg', '../data/imgs/data_mw/man/ma_38.jpg', '../data/imgs/data_mw/man/ma_170.jpg', '../data/imgs/data_mw/man/ma_140.jpg', '../data/imgs/data_mw/man/ma_2.jpg', '../data/imgs/data_mw/man/ma_107.jpg', '../data/imgs/data_mw/man/ma_196.jpg', '../data/imgs/data_mw/man/ma_81.jpg', '../data/imgs/data_mw/man/ma_79.jpg', '../data/imgs/data_mw/man/ma_129.jpg', '../data/imgs/data_mw/man/ma_29.jpg', '../data/imgs/data_mw/man/ma_84.jpg', '../data/imgs/data_mw/man/ma_124.jpg', '../data/imgs/data_mw/man/ma_128.jpg', '../data/imgs/data_mw/man/ma_143.jpg', '../data/imgs/data_mw/man/ma_46.jpg', '../data/imgs/data_mw/man/ma_4.jpg', '../data/imgs/data_mw/man/ma_193.jpg', '../data/imgs/data_mw/man/ma_192.jpg', '../data/imgs/data_mw/man/ma_1.jpg', '../data/imgs/data_mw/man/ma_103.jpg', '../data/imgs/data_mw/man/ma_150.jpg', '../data/imgs/data_mw/man/ma_63.jpg', '../data/imgs/data_mw/man/ma_162.jpg', '../data/imgs/data_mw/man/ma_158.jpg', '../data/imgs/data_mw/man/ma_43.jpg', '../data/imgs/data_mw/man/ma_135.jpg', '../data/imgs/data_mw/man/ma_3.jpg', '../data/imgs/data_mw/man/ma_91.jpg', '../data/imgs/data_mw/man/ma_188.jpg', '../data/imgs/data_mw/man/ma_85.jpg', '../data/imgs/data_mw/man/ma_125.jpg', '../data/imgs/data_mw/man/ma_37.jpg', '../data/imgs/data_mw/man/ma_53.jpg', '../data/imgs/data_mw/man/ma_160.jpg', '../data/imgs/data_mw/man/ma_156.jpg', '../data/imgs/data_mw/man/ma_54.jpg', '../data/imgs/data_mw/man/ma_179.jpg', '../data/imgs/data_mw/man/ma_166.jpg', '../data/imgs/data_mw/man/ma_96.jpg', '../data/imgs/data_mw/man/ma_64.jpg', '../data/imgs/data_mw/man/ma_174.jpg', '../data/imgs/data_mw/man/ma_40.jpg', '../data/imgs/data_mw/man/ma_80.jpg', '../data/imgs/data_mw/man/ma_142.jpg', '../data/imgs/data_mw/man/ma_34.jpg', '../data/imgs/data_mw/man/ma_184.jpg', '../data/imgs/data_mw/man/ma_126.jpg', '../data/imgs/data_mw/man/ma_164.jpg', '../data/imgs/data_mw/man/ma_186.jpg', '../data/imgs/data_mw/man/ma_115.jpg', '../data/imgs/data_mw/man/ma_41.jpg', '../data/imgs/data_mw/man/ma_11.jpg', '../data/imgs/data_mw/man/ma_6.jpg', '../data/imgs/data_mw/man/ma_169.jpg', '../data/imgs/data_mw/man/ma_116.jpg', '../data/imgs/data_mw/man/ma_13.jpg', '../data/imgs/data_mw/man/ma_137.jpg', '../data/imgs/data_mw/man/ma_86.jpg', '../data/imgs/data_mw/man/ma_173.jpg', '../data/imgs/data_mw/man/ma_17.jpg', '. ...
# ['../data/imgs/data_mw/woman/w_26.jpg', '../data/imgs/data_mw/woman/w_179.jpg', '../data/imgs/data_mw/woman/w_115.jpg', '../data/imgs/data_mw/woman/w_62.jpg', '../data/imgs/data_mw/woman/w_137.jpg', '../data/imgs/data_mw/woman/w_61.jpg', '../data/imgs/data_mw/woman/w_159.jpg', '../data/imgs/data_mw/woman/w_169.jpg', '../data/imgs/data_mw/woman/w_116.jpg', '../data/imgs/data_mw/woman/w_160.jpg', '../data/imgs/data_mw/woman/w_96.jpg', '../data/imgs/data_mw/woman/w_142.jpg', '../data/imgs/data_mw/woman/w_43.jpg', '../data/imgs/data_mw/woman/w_90.jpg', '../data/imgs/data_mw/woman/w_191.jpg', '../data/imgs/data_mw/woman/w_101.jpg', '../data/imgs/data_mw/woman/w_64.jpg', '../data/imgs/data_mw/woman/w_72.jpg', '../data/imgs/data_mw/woman/w_56.jpg', '../data/imgs/data_mw/woman/w_36.jpg', '../data/imgs/data_mw/woman/w_45.jpg', '../data/imgs/data_mw/woman/w_37.jpg', '../data/imgs/data_mw/woman/w_66.jpg', '../data/imgs/data_mw/woman/w_32.jpg', '../data/imgs/data_mw/woman/w_123.jpg', '../data/imgs/data_mw/woman/w_146.jpg', '../data/imgs/data_mw/woman/w_113.jpg', '../data/imgs/data_mw/woman/w_65.jpg', '../data/imgs/data_mw/woman/w_95.jpg', '../data/imgs/data_mw/woman/w_40.jpg', '../data/imgs/data_mw/woman/w_183.jpg', '../data/imgs/data_mw/woman/w_158.jpg', '../data/imgs/data_mw/woman/w_10.jpg', '../data/imgs/data_mw/woman/w_120.jpg', '../data/imgs/data_mw/woman/w_140.jpg', '../data/imgs/data_mw/woman/w_92.jpg', '../data/imgs/data_mw/woman/w_138.jpg', '../data/imgs/data_mw/woman/w_19.jpg', '../data/imgs/data_mw/woman/w_84.jpg', '../data/imgs/data_mw/woman/w_177.jpg', '../data/imgs/data_mw/woman/w_192.jpg', '../data/imgs/data_mw/woman/w_12.jpg', '../data/imgs/data_mw/woman/w_91.jpg', '../data/imgs/data_mw/woman/w_60.jpg', '../data/imgs/data_mw/woman/w_67.jpg', '../data/imgs/data_mw/woman/w_85.jpg', '../data/imgs/data_mw/woman/w_88.jpg', '../data/imgs/data_mw/woman/w_80.jpg', '../data/imgs/data_mw/woman/w_150.jpg', '../data/imgs/data_mw/woman/w_181.jpg', '../data/imgs/data_mw/woman/w_151.jpg', '../data/imgs/data_mw/woman/w_108.jpg', '../data/imgs/data_mw/woman/w_1.jpg', '../data/imgs/data_mw/woman/w_27.jpg', '../data/imgs/data_mw/woman/w_152.jpg', '../data/imgs/data_mw/woman/w_184.jpg', '../data/imgs/data_mw/woman/w_2.jpg', '../data/imgs/data_mw/woman/w_132.jpg', '../data/imgs/data_mw/woman/w_118.jpg', '../data/imgs/data_mw/woman/w_20.jpg', '../data/imgs/data_mw/woman/w_117.jpg', '../data/imgs/data_mw/woman/w_69.jpg', '../data/imgs/data_mw/woman/w_50.jpg', '../data/imgs/data_mw/woman/w_15.jpg', '../data/imgs/data_mw/woman/w_164.jpg', '../data/imgs/data_mw/woman/w_104.jpg', '../data/imgs/data_mw/woman/w_114.jpg', '../data/imgs/data_mw/woman/w_51.jpg', '../data/imgs/data_mw/woman/w_106.jpg', '../data/imgs/data_mw/woman/w_52.jpg', '../data/imgs/data_mw/woman/w_74.jpg', '../data/imgs/data_mw/woman/w_71.jpg', '../data/imgs/data_mw/woman/w_30.jpg', '../data/imgs/data_mw/woman/w_58.jpg', '../data/imgs/data_mw/woman/w_3.jpg', '../data/imgs/data_mw/woman/w_161.jpg', '../data/imgs/data_mw/woman/w_162.jpg', '../data/imgs/data_mw/woman/w_125.jpg', '../data/imgs/data_mw/woman/w_38.jpg', '../data/imgs/data_mw/woman/w_35.jpg', '../data/imgs/data_mw/woman/w_139.jpg', '../data/imgs/data_mw/woman/w_97.jpg', '../data/imgs/data_mw/woman/w_141.jpg', '../data/imgs/data_mw/woman/w_33.jpg', '../data/imgs/data_mw/woman/w_41.jpg', '../data/imgs/data_mw/woman/w_89.jpg', '../data/imgs/data_mw/woman/w_14.jpg', '../data/imgs/data_mw/woman/w_107.jpg', '../data/imgs/data_mw/woman/w_94.jpg', '../data/imgs/data_mw/woman/w_59.jpg', '../data/imgs/data_mw/woman/w_130.jpg', '../data/imgs/data_mw/woman/w_105.jpg', '../data/imgs/data_mw/woman/w_77.jpg', '../data/imgs/data_mw/woman/w_156.jpg', '../data/imgs/data_mw/woman/w_18.jpg', '../data/imgs/data_mw/woman/w_127.jpg', '../data/imgs/data_mw/woman/w_34.jpg', '../data/imgs/data_mw/woman/w_128.jpg', '../data/imgs/data_mw/woman/w_122.jpg', '../data/imgs/data_mw/woman/w_153.jpg', '../data/imgs/data_mw/woman/w_9.jpg', '../data/imgs/data ...

# %% [markdown]
# ### TEST 데이터로 확인하기

# %%
### train data 증강하기
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                   rotation_range=15,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True,
                                   vertical_flip=False)

train_augmented_images = train_datagen.flow(x_train, y_train,
                                            shuffle=True,
                                            batch_size=64)

### test 안 증강
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_augmented_images = test_datagen.flow(x_test, y_test,
                                            shuffle=True,
                                            batch_size=64)

# %%
def load_images_and_labels(files, label, size):
    images = [image.load_img(p, target_size=(size, size)) for p in files]  # warping
    labels = [label] * len(files)
    print(files)
    return images, labels

# %% [markdown]
# ### 모바일 넷 정답라벨

# %%
# 라벨 파일 URL
LABEL_URL = 'https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt'

# 라벨 파일 다운로드 및 읽기
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt', LABEL_URL)
with open(labels_path) as f:
    labels = f.readlines()

labels = [label.strip() for label in labels][1:]

# %% [markdown]
# ### 모델 결과 비교

# %%
trans_model = tf.keras.models.load_model('2_2_transfer_final_model.keras')
finet_model = tf.keras.models.load_model('3_2_fine_tuning_final_model.keras')
scrat_model = tf.keras.models.load_model('4_1_from_scratch.keras')

base_model = MobileNet(include_top=True, input_shape=(224,224,3), weights='imagenet')

# %%
mw_label = {0:"남자", 1:"여자"}

# %%
fig, ax = plt.subplots(figsize=(15,3))

for j in np.random.randint(1,64,1):

    print('\n정답 : ',end='')
    if test_augmented_images[0][1][j][0] == 1:
        print('남자',end='')
    else:
        print('여자', end='\n')
    
    ax.imshow((test_augmented_images[0][0][j]+1)/2);
    ax.grid(False)
    ax.set_axis_off()

    print(f'''
    베이스 라인 모델 예측 : {labels[base_model.predict(test_augmented_images[0][0][j].reshape(1,224,224,3), verbose=0).argmax()].__str__().strip()}
    전이 학습 모델 예측 : {mw_label[trans_model.predict(test_augmented_images[0][0][j].reshape(1,224,224,3), verbose=0).argmax()].__str__().strip()}
    파인 튜닝 모델 예측 : {mw_label[finet_model.predict(test_augmented_images[0][0][j].reshape(1,224,224,3), verbose=0).argmax()].__str__().strip()}
    직접 구축 모델 예측 : {mw_label[scrat_model.predict(test_augmented_images[0][0][j].reshape(1,224,224,3), verbose=0).argmax()].__str__().strip()}\
    ''', end='\n')
# Out:
# 정답 : 여자
#
#     베이스 라인 모델 예측 : fur coat
#     전이 학습 모델 예측 : 여자
#     파인 튜닝 모델 예측 : 여자
#     직접 구축 모델 예측 : 남자
