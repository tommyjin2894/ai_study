# %% [markdown]
# <b>이미지 라벨링</b><br>
# 라벨링 파일(메터데이터)와 이미지 파일을 파일을 별도로 작업<br>
# 파일명으로 매칭

# %%
import os
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers

# %%
import math
import numpy as np
from glob import glob
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
IMG_CHANNELS = 3
IMG_ROWS = 256
IMG_COLS = 256

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#define the convnet
def build(input_shape, classes):
    model = models.Sequential()
    model.add(layers.Convolution2D(256, (3, 3), activation='relu',
                        input_shape=input_shape))
    model.add(layers.MaxPooling2D(pool_size=(3, 3)))
    model.add(layers.Dropout(0.3))

    model.add(layers.Convolution2D(128, (6, 6), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3)))
    model.add(layers.Dropout(0.3))

    model.add(layers.Convolution2D(64, (6, 6), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3)))
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(classes, activation='softmax'))
    return model

# %% [markdown]
# ### 폴더안의 폴더들(라벨) 을 리스트로

# %%
folder_name = 'data/'
all_folders = os.listdir(folder_name)

CLASSES = len(all_folders)  # 폴더 안의 폴더들

# %%
image_vector = []
labels_vector = []
for foldername in all_folders:
    forder_list = os.listdir(folder_name + foldername)
    for filename in forder_list:
        try:
            file_path = folder_name + foldername +'/'+ filename
            print(file_path)
            img = image.load_img(file_path, target_size=(IMG_ROWS, IMG_COLS))
            img_array = image.img_to_array(img)
            image_vector.append(img_array)
            labels_vector.append(all_folders.index(foldername))
        except:
            pass
# Out:
# data/lion/l_23.jpg
# data/lion/l_25.jpg
# data/lion/l_41.jpg
# data/lion/l_8.jpg
# data/m_산/m_1.jpg
# data/m_산/m_10.jpg
# data/m_산/m_100.jpg
# data/m_산/m_101.jpg
# data/m_산/m_102.jpg
# data/m_산/m_103.jpg
# data/m_산/m_104.jpg
# data/m_산/m_105.jpg
# data/m_산/m_106.jpg
# data/m_산/m_107.jpg
# data/m_산/m_108.jpg
# data/m_산/m_109.jpg
# data/m_산/m_11.jpg
# data/m_산/m_110.jpg
# data/m_산/m_111.jpg
# data/m_산/m_112.jpg
# data/m_산/m_113.jpg
# data/m_산/m_114.jpg
# data/m_산/m_115.jpg
# data/m_산/m_116.jpg
# data/m_산/m_117.jpg
# data/m_산/m_118.jpg
# data/m_산/m_119.jpg
# data/m_산/m_12.jpg
# data/m_산/m_120.jpg
# data/m_산/m_121.jpg
# data/m_산/m_122.jpg
# data/m_산/m_123.jpg
# data/m_산/m_124.jpg
# data/m_산/m_125.jpg
# data/m_산/m_126.jpg
# data/m_산/m_127.jpg
# data/m_산/m_128.jpg
# data/m_산/m_129.jpg
# data/m_산/m_13.jpg
# data/m_산/m_130.jpg
# data/m_산/m_131.jpg
# data/m_산/m_132.jpg
# data/m_산/m_133.png
# data/m_산/m_134.jpg
# data/m_산/m_135.jpg
# data/m_산/m_136.jpg
# data/m_산/m_137.jpg
# data/m_산/m_138.jpg
# data/m_산/m_139.jpg
# data/m_산/m_14.jpg
# data/m_산/m_140.png
# data/m_산/m_141.jpg
# data/m_산/m_142.png
# data/m_산/m_144.jpg
# data/m_산/m_145.jpg
# data/m_산/m_146.jpg
# data/m_산/m_147.jpg
# data/m_산/m_148.jpg
# data/m_산/m_149.jpg
# data/m_산/m_15.JPG
# data/m_산/m_150.jpg
# data/m_산/m_151.jpg
# data/m_산/m_152.jpg
# data/m_산/m_153.jpg
# data/m_산/m_154.jpg
# data/m_산/m_155.jpg
# data/m_산/m_156.jpg
# data/m_산/m_158.jpg
# data/m_산/m_159.jpg
# data/m_산/m_16.jpg
# data/m_산/m_160.jpg
# data/m_산/m_161.jpg
# data/m_산/m_162.jpg
# data/m_산/m_163.jpg
# data/m_산/m_164.jpg
# data/m_산/m_166.jpg
# data/m_산/m_167.jpg
# data/m_산/m_168.jpg
# data/m_산/m_169.jpg
# data/m_산/m_17.jpg
# data/m_산/m_170.jpg
# data/m_산/m_171.jpg
# data/m_산/m_172.jpg
# data/m_산/m_173.jpg
# data/m_산/m_174.jpg
# data/m_산/m_186.jpg
# data/m_산/m_19.jpg
# data/m_산/m_192.jpg
# data/m_산/m_196.jpg
# data/m_산/m_197.jpg
# data/m_산/m_38.jpg
# data/m_산/m_47.jpg
# data/m_산/m_48.jpg
# data/m_산/m_53.jpg
# data/m_산/m_56.jpg
# data/m_산/m_66.jpg
# data/m_산/m_67.jpg
# data/m_산/m_7.jpg
# data/m_산/m_76.jpg
# data/m_산/m_8.jpg
# data/m_산/m_85.jpg
# data/m_산/m_86.jpg
# data/m_산/m_87.jpeg
# data/m_산/m_9.jpg
# data/m_산/m_90.jpg
# data/m_산/m_96.jpg
# data/m_산/m_97.jpg
# data/p_접시/p_1.jpg
# data/p_접시/p_10.jpg
# data/p_접시/p_11.JPG
# data/p_접시/p_12.jpg
# data/p_접시/p_13.png
# data/p_접시/p_14.jpg
# data/p_접시/p_15.jpg
# data/p_접시/p_16.jpg
# data/p_접시/p_17.jpg
# data/p_접시/p_18.jpg
# data/p_접시/p_19.jpg
# data/p_접시/p_2.JPG
# data/p_접시/p_20.jpg
# data/p_접시/p_21.jpg
# data/p_접시/p_22.jpg
# data/p_접시/p_23.jpg
# data/p_접시/p_24.jpg
# data/p_접시/p_25.jpg
# data/p_접시/p_26.jpg
# data/p_접시/p_27.jpg
# data/p_접시/p_28.jpg
# data/p_접시/p_29.jpg
# data/p_접시/p_3.jpg
# data/p_접시/p_30.JPG
# data/p_접시/p_31.JPG
# data/p_접시/p_32.JPG
# data/p_접시/p_33.jpg
# data/p_접시/p_34.jpg
# data/p_접시/p_35.jpg
# data/p_접시/p_36.jpg
# data/p_접시/p_37.jpg
# data/p_접시/p_38.jpg
# data/p_접시/p_39.jpg
# data/p_접시/p_4.jpg
# data/p_접시/p_40.jpg
# data/p_접시/p_41.jpeg
# data/p_접시/p_42.jpeg
# data/p_접시/p_43.jpg
# data/p_접시/p_44.jpg
# data/p_접시/p_45.jpg
# data/p_접시/p_46.JPG
# data/p_접시/p_47.jpg
# data/p_접시/p_48.jpg
# data/p_접시/p_49.jpg
# data/p_접시/p_5.jpg
# data/p_접시/p_50.jpg
# data/p_접시/p_6.jpg
# data/p_접시/p_7.jpg
# data/p_접시/p_8.JPG
# data/p_접시/p_9.jpg
# data/s_바다/s_1.jpg
# data/s_바다/s_10.jpg
# data/s_바다/s_10.png
# data/s_바다/s_100.jpg
# data/s_바다/s_101.jpg
# data/s_바다/s_102.jpg
# data/s_바다/s_103.gif
# data/s_바다/s_104.jpg
# data/s_바다/s_105.jpg
# data/s_바다/s_106.jpg
# data/s_바다/s_107.jpg
# data/s_바다/s_108.jpg
# data/s_바다/s_109.jpg
# data/s_바다/s_11.jpg
# data/s_바다/s_110.jpg
# data/s_바다/s_111.jpg
# data/s_바다/s_112.jpg
# data/s_바다/s_113.jpg
# data/s_바다/s_114.jpg
# data/s_바다/s_115.jpg
# data/s_바다/s_116.png
# data/s_바다/s_117.jpg
# data/s_바다/s_118.jpg
# data/s_바다/s_119.jpg
# data/s_바다/s_12.jpg
# data/s_바다/s_120.jpg
# data/s_바다/s_121.jpg
# data/s_바다/s_122.jpg
# data/s_바다/s_123.jpg
# data/s_바다/s_124.jpg
# data/s_바다/s_125.jpg
# data/s_바다/s_126.jpg
# data/s_바다/s_127.jpg
# data/s_바다/s_128.jpg
# data/s_바다/s_129.jpg
# data/s_바다/s_13.jpg
# data/s_바다/s_130.jpg
# data/s_바다/s_131.jpg
# data/s_바다/s_132.jpg
# data/s_바다/s_133.jpg
# data/s_바다/s_134.jpg
# data/s_바다/s_135.jpg
# data/s_바다/s_136.jpg
# data/s_바다/s_137.jpg
# data/s_바다/s_138.jpg
# data/s_바다/s_139.jpg
# data/s_바다/s_14.jpg
# data/s_바다/s_140.jpg
# data/s_바다/s_141.jpg
# data/s_바다/s_142.jpg
# data/s_바다/s_143.jpg
# data/s_바다/s_144.jpg
# data/s_바다/s_145.jpg
# data/s_바다/s_146.jpg
# data/s_바다/s_147.jpg
# data/s_바다/s_148.jpg
# data/s_바다/s_149.jpg
# data/s_바다/s_15.jpg
# data/s_바다/s_150.png
# data/s_바다/s_151.jpg
# data/s_바다/s_152.jpg
# data/s_바다/s_153.jpg
# data/s_바다/s_154.jpg
# data/s_바다/s_155.jpg
# data/s_바다/s_156.jpeg
# data/s_바다/s_158.jpg
# data/s_바다/s_159.jpg
# data/s_바다/s_16.jpg
# data/s_바다/s_160.JPG
# data/s_바다/s_161.jpg
# data/s_바다/s_162.jpg
# data/s_바다/s_163.jpg
# data/s_바다/s_164.jpg
# data/s_바다/s_165.jpg
# data/s_바다/s_166.jpg
# data/s_바다/s_167.jpg
# data/s_바다/s_168.jpg
# data/s_바다/s_169.jpg
# data/s_바다/s_17.jpg
# data/s_바다/s_170.jpg
# data/s_바다/s_171.jpg
# data/s_바다/s_172.jpg
# data/s_바다/s_173.jpg
# data/s_바다/s_174.jpg
# data/s_바다/s_175.jpg
# data/s_바다/s_176.jpg
# data/s_바다/s_177.JPG
# data/s_바다/s_178.jpg
# data/s_바다/s_179.jpg
# data/s_바다/s_18.jpg
# data/s_바다/s_180.jpg
# data/s_바다/s_181.jpg
# data/s_바다/s_182.jpg
# data/s_바다/s_183.jpg
# data/s_바다/s_184.jpg
# data/s_바다/s_185.jpg
# data/s_바다/s_186.jpg
# data/s_바다/s_187.JPG
# data/s_바다/s_188.jpg
# data/s_바다/s_189.jpg
# data/s_바다/s_19.jpg
# data/s_바다/s_190.jpg
# data/s_바다/s_191.jpg
# data/s_바다/s_192.jpg
# data/s_바다/s_193.jpg
# data/s_바다/s_194.jpg
# data/s_바다/s_195.jpg
# data/s_바다/s_196.jpg
# data/s_바다/s_197.jpg
# data/s_바다/s_198.jpg
# data/s_바다/s_199.jpg
# data/s_바다/s_2.jpg
# data/s_바다/s_20.jpg
# data/s_바다/s_200.jpg
# data/s_바다/s_21.jpg
# data/s_바다/s_22.jpg
# data/s_바다/s_23.PNG
# data/s_바다/s_24.PNG
# data/s_바다/s_25.jpg
# data/s_바다/s_26.jpg
# data/s_바다/s_27.jpg
# data/s_바다/s_28.jpg
# data/s_바다/s_29.jpg
# data/s_바다/s_3.jpg
# data/s_바다/s_30.jpg
# data/s_바다/s_31.jpg
# data/s_바다/s_32.jpg
# data/s_바다/s_33.jpg
# data/s_바다/s_34.jpg
# data/s_바다/s_35.jpg
# data/s_바다/s_36.jpg
# data/s_바다/s_37.jpg
# data/s_바다/s_38.jpg
# data/s_바다/s_39.jpg
# data/s_바다/s_4.jpg
# data/s_바다/s_40.jpg
# data/s_바다/s_41.jpg
# data/s_바다/s_42.png
# data/s_바다/s_43.jpg
# data/s_바다/s_44.jpg
# data/s_바다/s_45.jpg
# data/s_바다/s_46.jpg
# data/s_바다/s_47.jpg
# data/s_바다/s_48.jpg
# data/s_바다/s_49.jpg
# data/s_바다/s_5.jpeg
# data/s_바다/s_5.jpg
# data/s_바다/s_50.jpg
# data/s_바다/s_51.png
# data/s_바다/s_52.jpg
# data/s_바다/s_53.jpg
# data/s_바다/s_54.jpg
# data/s_바다/s_55.jpg
# data/s_바다/s_56.jpg
# data/s_바다/s_57.jpg
# data/s_바다/s_58.jpg
# data/s_바다/s_59.jpg
# c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\PIL\Image.py:3368: DecompressionBombWarning: Image size (109542160 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# data/s_바다/s_6.jpeg
# data/s_바다/s_6.jpg
# data/s_바다/s_60.jpg
# data/s_바다/s_61.jpg
# data/s_바다/s_62.jpg
# data/s_바다/s_63.jpg
# data/s_바다/s_64.jpg
# data/s_바다/s_65.jpg
# data/s_바다/s_66.JPG
# data/s_바다/s_67.jpg
# data/s_바다/s_68.jpg
# data/s_바다/s_69.jpg
# data/s_바다/s_7.jpg
# data/s_바다/s_70.jpg
# data/s_바다/s_71.jpg
# data/s_바다/s_72.jpg
# data/s_바다/s_73.jpg
# data/s_바다/s_74.jpg
# data/s_바다/s_75.jpg
# data/s_바다/s_76.jpg
# data/s_바다/s_77.jpg
# data/s_바다/s_78.jpg
# data/s_바다/s_79.jpg
# data/s_바다/s_8.jpg
# data/s_바다/s_80.jpg
# data/s_바다/s_81.jpg
# data/s_바다/s_82.jpg
# data/s_바다/s_83.jpg
# data/s_바다/s_84.jpg
# data/s_바다/s_85.jpg
# data/s_바다/s_86.jpg
# data/s_바다/s_87.jpg
# data/s_바다/s_88.jpg
# data/s_바다/s_89.jpg
# data/s_바다/s_9.jpg
# data/s_바다/s_90.jpg
# data/s_바다/s_91.jpg
# data/s_바다/s_92.jpg
# data/s_바다/s_93.jpg
# data/s_바다/s_94.jpg
# data/s_바다/s_95.jpg
# data/s_바다/s_96.JPG
# data/s_바다/s_97.jpg
# data/s_바다/s_98.jpg
# data/s_바다/s_99.jpg
# data/tigar/t_2.jpg
# data/tigar/t_22.jpg
# data/tigar/t_25.jpg
# data/tigar/t_3.jpg
# data/tigar/t_36.png

# %%
len(labels_vector)
# Out:
# 364

# %%
image_vector[0].shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(image_vector[356]/255)

# %%
# numpy 배열로 변환
image_vector = np.array(image_vector)
labels_vector = np.array(labels_vector)

# %%
y = labels_vector

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_vector, y, test_size=0.20, random_state=0)

# %%
X_train.shape
# Out:
# (291, 256, 256, 3)

# %%
X_train, X_test = X_train / 255, X_test / 255
# convert to categorical
# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, CLASSES)
y_test = tf.keras.utils.to_categorical(y_test, CLASSES)

# %%
y_train[2]
# Out:
# array([0., 0., 0., 1., 0.], dtype=float32)

# %%
CLASSES
# Out:
# 5

# %%
model=build((IMG_ROWS, IMG_COLS, IMG_CHANNELS), CLASSES)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 256)     7168
#
#  max_pooling2d (MaxPooling2D  (None, 84, 84, 256)      0
#  )
#
#  dropout (Dropout)           (None, 84, 84, 256)       0
#
#  conv2d_1 (Conv2D)           (None, 79, 79, 128)       1179776
#
#  max_pooling2d_1 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 26, 26, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        294976
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 32)                100384
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 1,582,469
# Trainable params: 1,582,469
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizers.RMSprop(learning_rate=0.001), metrics=['accuracy'])

history = model.fit(X_train, y_train, batch_size=4, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 66/66 [==============================] - 22s 209ms/step - loss: 1.3966 - accuracy: 0.5364 - val_loss: 0.9328 - val_accuracy: 0.3667
# Epoch 2/50
# 66/66 [==============================] - 8s 124ms/step - loss: 1.0939 - accuracy: 0.4981 - val_loss: 0.7397 - val_accuracy: 0.6667
# Epoch 3/50
# 66/66 [==============================] - 10s 156ms/step - loss: 1.0928 - accuracy: 0.5670 - val_loss: 0.9489 - val_accuracy: 0.6667
# Epoch 4/50
# 66/66 [==============================] - 17s 253ms/step - loss: 1.0181 - accuracy: 0.5441 - val_loss: 0.8319 - val_accuracy: 0.7333
# Epoch 5/50
# 66/66 [==============================] - 4s 59ms/step - loss: 1.0525 - accuracy: 0.6054 - val_loss: 0.7511 - val_accuracy: 0.7333
# Epoch 6/50
# 66/66 [==============================] - 4s 64ms/step - loss: 0.9757 - accuracy: 0.6169 - val_loss: 0.9284 - val_accuracy: 0.6000
# Epoch 7/50
# 66/66 [==============================] - 4s 61ms/step - loss: 0.9507 - accuracy: 0.6322 - val_loss: 0.9633 - val_accuracy: 0.6333
# Epoch 8/50
# 66/66 [==============================] - 4s 66ms/step - loss: 0.9098 - accuracy: 0.6360 - val_loss: 0.9069 - val_accuracy: 0.6000
# Epoch 9/50
# 66/66 [==============================] - 4s 62ms/step - loss: 0.9015 - accuracy: 0.6475 - val_loss: 1.4802 - val_accuracy: 0.6000
# Epoch 10/50
# 66/66 [==============================] - 4s 65ms/step - loss: 0.8459 - accuracy: 0.6590 - val_loss: 5.4232 - val_accuracy: 0.2000
# Epoch 11/50
#  3/66 [>.............................] - ETA: 4s - loss: 1.3225 - accuracy: 0.7500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 model.compile(loss='categorical_crossentropy', optimizer=optimizers.RMSprop(learning_rate=0.001), metrics=['accuracy'])
# ----> 3 history = model.fit(X_train, y_train, batch_size=4, epochs=50, validation_split=0.1)
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\crazy\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train','val'])
plt.show()

# %%
score = model.evaluate(X_test, y_test)
print("\nTest loss:", score[0])
print('Test accuracy:', score[1])
# Out:
# 3/3 [==============================] - 1s 333ms/step - loss: 4.5752 - accuracy: 0.6486
#
# Test loss: 4.575197696685791
# Test accuracy: 0.6486486196517944

# %%
X_test[27].shape
# Out:
# (256, 256, 3)

# %%
i = 4
predicted = all_folders[model.predict(X_test[i].reshape(1,256,256,3), verbose=0).argmax()]
real = all_folders[y_test[i].argmax()]
print("정답라벨:",real, "예측:",predicted)
plt.imshow(X_test[i])
plt.show()
# Out:
# 정답라벨: man 예측: woman

# %%
# for i in range(len(X_test)):
#     predicted = all_folders[model.predict(X_test[i].reshape(1,256,256,3), verbose=0).argmax()]
#     real = all_folders[y_test[i].argmax()]
#     if predicted != real:
#         print("정답라벨:",real, "예측:",predicted)
#         plt.imshow(X_test[i])
#         plt.show()
