# %% [markdown]
# # 0. 목표
#
# * pandas의 기본적인 사용법을 안다.
# * json 파일을 다룰 줄 안다.
# * 지도 시각화를 할 수 있다.

# %% [markdown]
# # 1. 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import json
import folium

# %%
print("numpy: ", np.__version__)
print("pandas: ", pd.__version__)
print("matplotlib: ", matplotlib.__version__)
print("json: ", json.__version__)
print("folium: ", folium.__version__)
# Out:
# numpy:  1.23.5
# pandas:  1.5.1
# matplotlib:  3.6.2
# json:  2.0.9
# folium:  0.16.0

# %% [markdown]
# # 2. 데이터 불러오기

# %%
# 로컬
df = pd.read_csv("../data/crime_in_Seoul.csv", 
                    encoding="cp949")
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     29 non-null     object
#  1   살인 발생   29 non-null     int64
#  2   살인 검거   29 non-null     int64
#  3   강도 발생   29 non-null     int64
#  4   강도 검거   29 non-null     int64
#  5   강간 발생   29 non-null     int64
#  6   강간 검거   29 non-null     int64
#  7   절도 발생   29 non-null     object
#  8   절도 검거   29 non-null     object
#  9   폭력 발생   29 non-null     object
#  10  폭력 검거   29 non-null     object
# dtypes: int64(6), object(5)
# memory usage: 2.6+ KB

# %% [markdown]
# * 데이터 수치에 대한 정의를 정확히!
# * 콤마(,)가 있을 경우
# * index_col = 0의 의미

# %%
crime = pd.read_csv("../data/crime_in_Seoul.csv", 
                    encoding="cp949",
                    thousands=",",
                    index_col = 0)

# %%
# 발생과 검거가 같으면 100% 검거라고 할 수 있는가?
crime
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 용산서       5      5     14     14    194    173   1557    587   2050   1704
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# 동작서       5      5      9      5    285    139   1865    661   1910   1587
# 광진서       4      4     14     26    240    220   3026   1277   2625   2180
# 서부서       2      2      2      1     70     59    819    293   1192   1038
# 강북서       7      8     14     13    153    126   1434    618   2649   2348
# 중랑서      13     12     11      9    187    148   2135    829   2847   2407
# 강남서       3      3     15     12    300    225   2411    984   2465   2146
# 관악서       9      8     12     14    320    221   2706    827   3298   2642
# 강서서       7      8     13     13    262    191   2096   1260   3207   2718
# 강동서       4      3      6      8    156    123   2366    789   2712   2248
# 종암서       3      3      3      3     64     53    832    332   1015    840
# 구로서       8      6     15     11    281    164   2335    889   3007   2432
# 서초서       7      4      8      5    334    193   1982    905   1852   1607
# 양천서       3      5      6      3    120    105   1890    672   2509   2030
# 송파서      11     10     13     10    220    178   3239   1129   3295   2786
# 노원서      10     10      7      7    197    121   2193    801   2723   2329
# 방배서       1      2      1      1     59     56    653    186    547    491
# 도봉서       3      3      9     10    102    106   1063    478   1487   1303
# 수서서      10      7      6      6    149    124   1439    666   1819   1559

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 중부서 to 수서서
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   살인 발생   29 non-null     int64
#  1   살인 검거   29 non-null     int64
#  2   강도 발생   29 non-null     int64
#  3   강도 검거   29 non-null     int64
#  4   강간 발생   29 non-null     int64
#  5   강간 검거   29 non-null     int64
#  6   절도 발생   29 non-null     int64
#  7   절도 검거   29 non-null     int64
#  8   폭력 발생   29 non-null     int64
#  9   폭력 검거   29 non-null     int64
# dtypes: int64(10)
# memory usage: 2.5+ KB

# %%
crime.columns
# Out:
# Index(['살인 발생', '살인 검거', '강도 발생', '강도 검거', '강간 발생', '강간 검거', '절도 발생', '절도 검거',
#        '폭력 발생', '폭력 검거'],
#       dtype='object')

# %% [markdown]
# # 3. 데이터에 접근하기

# %% [markdown]
# * 특정 feature만 보자

# %%
crime_occurs = crime.columns[::2]
crime_occurs
# Out:
# Index(['살인 발생', '강도 발생', '강간 발생', '절도 발생', '폭력 발생'], dtype='object')

# %%
## "** 검거" feature name만 모아보자.
crime_arrest = crime.columns[1::2]
crime_arrest
# Out:
# Index(['살인 검거', '강도 검거', '강간 검거', '절도 검거', '폭력 검거'], dtype='object')

# %%
crime[crime_occurs]
# Out:
#       살인 발생  강도 발생  강간 발생  절도 발생  폭력 발생
# 관서명
# 중부서       2      3    105   1395   1355
# 종로서       3      6    115   1070   1278
# 남대문서      1      6     65   1153    869
# 서대문서      2      5    154   1812   2056
# 혜화서       3      5     96   1114   1015
# 용산서       5     14    194   1557   2050
# 성북서       2      2     86    953   1194
# 동대문서      5     13    173   1981   2548
# 마포서       8     14    294   2555   2983
# 영등포서     14     22    295   2964   3572
# 성동서       4      9    126   1607   1612
# 동작서       5      9    285   1865   1910
# 광진서       4     14    240   3026   2625
# 서부서       2      2     70    819   1192
# 강북서       7     14    153   1434   2649
# 중랑서      13     11    187   2135   2847
# 강남서       3     15    300   2411   2465
# 관악서       9     12    320   2706   3298
# 강서서       7     13    262   2096   3207
# 강동서       4      6    156   2366   2712
# 종암서       3      3     64    832   1015
# 구로서       8     15    281   2335   3007
# 서초서       7      8    334   1982   1852
# 양천서       3      6    120   1890   2509
# 송파서      11     13    220   3239   3295
# 노원서      10      7    197   2193   2723
# 방배서       1      1     59    653    547
# 도봉서       3      9    102   1063   1487
# 수서서      10      6    149   1439   1819

# %% [markdown]
# * 특정 sample만 보자

# %%
crime.iloc[0]["폭력 검거"]
# Out:
# 1170

# %%
crime.loc["중부서"]["폭력 검거"]
# Out:
# 1170

# %%
police_sample = ["강남서", "수서서", "강서서", "마포서"]

# %%
crime.loc[police_sample]
# Out:
#      살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 관서명
# 강남서      3      3     15     12    300    225   2411    984   2465   2146
# 수서서     10      7      6      6    149    124   1439    666   1819   1559
# 강서서      7      8     13     13    262    191   2096   1260   3207   2718
# 마포서      8      8     14     10    294    247   2555    813   2983   2519

# %%
## "동"이 들어 있는 관서명만 추출하시오.

police_dong = [i for i in crime.index if "동" in i]
police_dong
# Out:
# ['동대문서', '성동서', '동작서', '강동서']

# %%
## police_dong에 속한 sample만 추출하시오.

crime.loc[police_dong]
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 관서명
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# 동작서       5      5      9      5    285    139   1865    661   1910   1587
# 강동서       4      3      6      8    156    123   2366    789   2712   2248

# %% [markdown]
# * 특정 조건을 만족하는 sample을 뽑자

# %%
crime["절도 발생"].mean()
# Out:
# 1815.344827586207

# %%
crime["절도 발생"] > crime["절도 발생"].mean()
# Out:
# 관서명
# 중부서     False
# 종로서     False
# 남대문서    False
# 서대문서    False
# 혜화서     False
# 용산서     False
# 성북서     False
# 동대문서     True
# 마포서      True
# 영등포서     True
# 성동서     False
# 동작서      True
# 광진서      True
# 서부서     False
# 강북서     False
# 중랑서      True
# 강남서      True
# 관악서      True
# 강서서      True
# 강동서      True
# 종암서     False
# 구로서      True
# 서초서      True
# 양천서      True
# 송파서      True
# 노원서      True
# 방배서     False
# 도봉서     False
# 수서서     False
# Name: 절도 발생, dtype: bool

# %%
crime[crime["절도 발생"] > crime["절도 발생"].mean()]
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 관서명
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 동작서       5      5      9      5    285    139   1865    661   1910   1587
# 광진서       4      4     14     26    240    220   3026   1277   2625   2180
# 중랑서      13     12     11      9    187    148   2135    829   2847   2407
# 강남서       3      3     15     12    300    225   2411    984   2465   2146
# 관악서       9      8     12     14    320    221   2706    827   3298   2642
# 강서서       7      8     13     13    262    191   2096   1260   3207   2718
# 강동서       4      3      6      8    156    123   2366    789   2712   2248
# 구로서       8      6     15     11    281    164   2335    889   3007   2432
# 서초서       7      4      8      5    334    193   1982    905   1852   1607
# 양천서       3      5      6      3    120    105   1890    672   2509   2030
# 송파서      11     10     13     10    220    178   3239   1129   3295   2786
# 노원서      10     10      7      7    197    121   2193    801   2723   2329

# %%
# "절도 발생"이 2000건 이상이고, "살인 발생"이 5건 미만인 데이터를 추출하자.

crime[(crime["절도 발생"] >= 2000) & (crime["살인 발생"] < 5)]
# Out:
#      살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 관서명
# 광진서      4      4     14     26    240    220   3026   1277   2625   2180
# 강남서      3      3     15     12    300    225   2411    984   2465   2146
# 강동서      4      3      6      8    156    123   2366    789   2712   2248

# %%
# "절도 검거"이 500건 이하이거나 "폭력 검거"이 1000건 미만인 데이터를 추출하자.

crime[(crime["절도 검거"] <= 500) | (crime["폭력 검거"] < 1000)]
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 서부서       2      2      2      1     70     59    819    293   1192   1038
# 종암서       3      3      3      3     64     53    832    332   1015    840
# 방배서       1      2      1      1     59     56    653    186    547    491
# 도봉서       3      3      9     10    102    106   1063    478   1487   1303

# %%
## "강도 발생"보다 "강도 검거"가 많은 데이터를 추출하시오.
crime[crime["강도 발생"] < crime["강도 검거"]][["강도 발생", "강도 검거"]]
# Out:
#      강도 발생  강도 검거
# 관서명
# 광진서     14     26
# 관악서     12     14
# 강동서      6      8
# 도봉서      9     10

# %% [markdown]
# # 4. feature 생성하기

# %%
crime.sum()
# Out:
# 살인 발생      159
# 살인 검거      148
# 강도 발생      263
# 강도 검거      242
# 강간 발생     5202
# 강간 검거     3887
# 절도 발생    52645
# 절도 검거    20228
# 폭력 발생    61691
# 폭력 검거    52118
# dtype: int64

# %%
crime.sum(axis = 0)
# Out:
# 살인 발생      159
# 살인 검거      148
# 강도 발생      263
# 강도 검거      242
# 강간 발생     5202
# 강간 검거     3887
# 절도 발생    52645
# 절도 검거    20228
# 폭력 발생    61691
# 폭력 검거    52118
# dtype: int64

# %%
crime.sum(axis = 1)
# Out:
# 관서명
# 중부서      4576
# 종로서      4061
# 남대문서     3320
# 서대문서     6608
# 혜화서      3587
# 용산서      6303
# 성북서      3735
# 동대문서     7925
# 마포서      9451
# 영등포서    11021
# 성동서      5481
# 동작서      6471
# 광진서      9616
# 서부서      3478
# 강북서      7370
# 중랑서      8598
# 강남서      8564
# 관악서     10057
# 강서서      9775
# 강동서      8415
# 종암서      3148
# 구로서      9148
# 서초서      6897
# 양천서      7343
# 송파서     10891
# 노원서      8398
# 방배서      1997
# 도봉서      4564
# 수서서      5785
# dtype: int64

# %%
crime["total"] = crime.sum(axis = 1)
crime
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 용산서       5      5     14     14    194    173   1557    587   2050   1704
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# 동작서       5      5      9      5    285    139   1865    661   1910   1587
# 광진서       4      4     14     26    240    220   3026   1277   2625   2180
# 서부서       2      2      2      1     70     59    819    293   1192   1038
# 강북서       7      8     14     13    153    126   1434    618   2649   2348
# 중랑서      13     12     11      9    187    148   2135    829   2847   2407
# 강남서       3      3     15     12    300    225   2411    984   2465   2146
# 관악서       9      8     12     14    320    221   2706    827   3298   2642
# 강서서       7      8     13     13    262    191   2096   1260   3207   2718
# 강동서       4      3      6      8    156    123   2366    789   2712   2248
# 종암서       3      3      3      3     64     53    832    332   1015    840
# 구로서       8      6     15     11    281    164   2335    889   3007   2432
# 서초서       7      4      8      5    334    193   1982    905   1852   1607
# 양천서       3      5      6      3    120    105   1890    672   2509   2030
# 송파서      11     10     13     10    220    178   3239   1129   3295   2786
# 노원서      10     10      7      7    197    121   2193    801   2723   2329
# 방배서       1      2      1      1     59     56    653    186    547    491
# 도봉서       3      3      9     10    102    106   1063    478   1487   1303
# 수서서      10      7      6      6    149    124   1439    666   1819   1559
#
#       total
# 관서명
# 중부서    4576
# 종로서    4061
# 남대문서   3320
# 서대문서   6608
# 혜화서    3587
# 용산서    6303
# 성북서    3735
# 동대문서   7925
# 마포서    9451
# 영등포서  11021
# 성동서    5481
# 동작서    6471
# 광진서    9616
# 서부서    3478
# 강북서    7370
# 중랑서    8598
# 강남서    8564
# 관악서   10057
# 강서서    9775
# 강동서    8415
# 종암서    3148
# 구로서    9148
# 서초서    6897
# 양천서    7343
# 송파서   10891
# 노원서    8398
# 방배서    1997
# 도봉서    4564
# 수서서    5785

# %%
## crime에 "occurs_total"과 "arrest_total" 열을 추가하시오
crime["occurs_total"] = crime[crime_occurs].sum(axis=1)
crime["arrest_total"] = crime[crime_arrest].sum(axis=1)
crime
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 용산서       5      5     14     14    194    173   1557    587   2050   1704
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# 동작서       5      5      9      5    285    139   1865    661   1910   1587
# 광진서       4      4     14     26    240    220   3026   1277   2625   2180
# 서부서       2      2      2      1     70     59    819    293   1192   1038
# 강북서       7      8     14     13    153    126   1434    618   2649   2348
# 중랑서      13     12     11      9    187    148   2135    829   2847   2407
# 강남서       3      3     15     12    300    225   2411    984   2465   2146
# 관악서       9      8     12     14    320    221   2706    827   3298   2642
# 강서서       7      8     13     13    262    191   2096   1260   3207   2718
# 강동서       4      3      6      8    156    123   2366    789   2712   2248
# 종암서       3      3      3      3     64     53    832    332   1015    840
# 구로서       8      6     15     11    281    164   2335    889   3007   2432
# 서초서       7      4      8      5    334    193   1982    905   1852   1607
# 양천서       3      5      6      3    120    105   1890    672   2509   2030
# 송파서      11     10     13     10    220    178   3239   1129   3295   2786
# 노원서      10     10      7      7    197    121   2193    801   2723   2329
# 방배서       1      2      1      1     59     56    653    186    547    491
# 도봉서       3      3      9     10    102    106   1063    478   1487   1303
# 수서서      10      7      6      6    149    124   1439    666   1819   1559
#
#       total  occurs_total  arrest_total
# 관서명
# 중부서    4576          2860          1716
# 종로서    4061          2472          1589
# 남대문서   3320          2094          1226
# 서대문서   6608          4029          2579
# 혜화서    3587          2233          1354
# 용산서    6303          3820          2483
# 성북서    3735          2237          1498
# 동대문서   7925          4720          3205
# 마포서    9451          5854          3597
# 영등포서  11021          6867          4154
# 성동서    5481          3358          2123
# 동작서    6471          4074          2397
# 광진서    9616          5909          3707
# 서부서    3478          2085          1393
# 강북서    7370          4257          3113
# 중랑서    8598          5193          3405
# 강남서    8564          5194          3370
# 관악서   10057          6345          3712
# 강서서    9775          5585          4190
# 강동서    8415          5244          3171
# 종암서    3148          1917          1231
# 구로서    9148          5646          3502
# 서초서    6897          4183          2714
# 양천서    7343          4528          2815
# 송파서   10891          6778          4113
# 노원서    8398          5130          3268
# 방배서    1997          1261           736
# 도봉서    4564          2664          1900
# 수서서    5785          3423          2362

# %% [markdown]
# # 5. json에서 필요한 정보 가져오기

# %%
with open('../data/police_station_info.json','r') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'police_name': '서울종로경찰서',
#   'address_components': [{'long_name': '41',
#     'short_name': '41',
#     'types': ['premise']},
#    {'long_name': '인사동5길',
#     'short_name': '인사동5길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '110-160',
#     'short_name': '110-160',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 인사동5길 41',
#   'geometry': {'location': {'lat': 37.571824, 'lng': 126.9841533},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5731729802915,
#      'lng': 126.9855022802915},
#     'southwest': {'lat': 37.5704750197085, 'lng': 126.9828043197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJRVgVHsOifDURFhKFchVo22I',
#   'plus_code': {'compound_code': 'HXCM+PM 대한민국 서울특별시',
#    'global_code': '8Q98HXCM+PM'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울용산경찰서',
#   'address_components': [{'long_name': '329',
#     'short_name': '329',
#     'types': ['premise']},
#    {'long_name': '백범로',
#     'short_name': '백범로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '용산구',
#     'short_name': '용산구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '04316', 'short_name': '04316', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 용산구 백범로 329',
#   'geometry': {'location': {'lat': 37.5387099, 'lng': 126.9659183},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5400588802915,
#      'lng': 126.9672672802915},
#     'southwest': {'lat': 37.5373609197085, 'lng': 126.9645693197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJhbgEHxKifDURLOHanwAKdJI',
#   'plus_code': {'compound_code': 'GXQ8+F9 대한민국 서울특별시',
#    'global_code': '8Q98GXQ8+F9'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울서대문경찰서',
#   'address_components': [{'long_name': '13',
#     'short_name': '13',
#     'types': ['premise']},
#    {'long_name': '충정로',
#     'short_name': '충정로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '서대문구',
#     'short_name': '서대문구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '03737', 'short_name': '03737', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서대문구 충정로 13',
#   'geometry': {'location': {'lat': 37.560607, 'lng': 126.9626106},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5619559802915,
#      'lng': 126.9639595802915},
#     'southwest': {'lat': 37.5592580197085, 'lng': 126.9612616197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJCZy8woiifDURz7CV6Khfi18',
#   'plus_code': {'compound_code': 'HX67+62 대한민국 서울특별시',
#    'global_code': '8Q98HX67+62'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울중부경찰서',
#   'address_components': [{'long_name': '27',
#     'short_name': '27',
#     'types': ['premise']},
#    {'long_name': '수표로',
#     'short_name': '수표로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '100-032',
#     'short_name': '100-032',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 수표로 27',
#   'geometry': {'location': {'lat': 37.56361709999999, 'lng': 126.9896517},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5649660802915,
#      'lng': 126.9910006802915},
#     'southwest': {'lat': 37.5622681197085, 'lng': 126.9883027197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJc-9q5uSifDURLhQmr5wkXmc',
#   'plus_code': {'compound_code': 'HX7Q+CV 대한민국 서울특별시',
#    'global_code': '8Q98HX7Q+CV'},
#   'types': ['establishment', 'point_of_interest']},
#  {'police_name': '서울혜화경찰서',
#   'address_components': [{'long_name': '112-16',
#     'short_name': '112-16',
#     'types': ['premise']},
#    {'long_name': '창경궁로',
#     'short_name': '창경궁로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '03130', 'short_name': '03130', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 창경궁로 112-16',
#   'geometry': {'location': {'lat': 37.5719679, 'lng': 126.9989574},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.57331688029149,
#      'lng': 127.0003063802915},
#     'southwest': {'lat': 37.57061891970849, 'lng': 126.9976084197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJc0PIxSCjfDURWuMVOPZrMTM',
#   'plus_code': {'compound_code': 'HXCX+QH 대한민국 서울특별시',
#    'global_code': '8Q98HXCX+QH'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울성북경찰서',
#   'address_components': [{'long_name': '170',
#     'short_name': '170',
#     'types': ['premise']},
#    {'long_name': '보문로',
#     'short_name': '보문로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '성북구',
#     'short_name': '성북구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '02848', 'short_name': '02848', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 성북구 보문로 170',
#   'geometry': {'location': {'lat': 37.5898228, 'lng': 127.0163427},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5911717802915,
#      'lng': 127.0176916802915},
#     'southwest': {'lat': 37.5884738197085, 'lng': 127.0149937197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJCzgT1Me8fDURiSAT03pwJPg',
#   'plus_code': {'compound_code': 'H2Q8+WG 대한민국 서울특별시',
#    'global_code': '8Q99H2Q8+WG'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울노원경찰서',
#   'address_components': [{'long_name': '노원경찰서',
#     'short_name': '노원경찰서',
#     'types': ['bus_station',
#      'establishment',
#      'point_of_interest',
#      'transit_station']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 노원경찰서',
#   'geometry': {'location': {'lat': 37.641836, 'lng': 127.072198},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 37.6431849802915,
#      'lng': 127.0735469802915},
#     'southwest': {'lat': 37.6404870197085, 'lng': 127.0708490197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJMyFPS2W5fDURunT7I9WYI3c',
#   'plus_code': {'compound_code': 'J3RC+PV 대한민국 서울특별시',
#    'global_code': '8Q99J3RC+PV'},
#   'types': ['bus_station',
#    'establishment',
#    'point_of_interest',
#    'transit_station']},
#  {'police_name': '서울마포경찰서',
#   'address_components': [{'long_name': '183',
#     'short_name': '183',
#     'types': ['premise']},
#    {'long_name': '마포대로',
#     'short_name': '마포대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '마포구',
#     'short_name': '마포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '121-010',
#     'short_name': '121-010',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 마포구 마포대로 183',
#   'geometry': {'location': {'lat': 37.550814, 'lng': 126.954028},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5521629802915,
#      'lng': 126.9553769802915},
#     'southwest': {'lat': 37.5494650197085, 'lng': 126.9526790197085}}},
#   'place_id': 'ChIJc8rsjHWifDUR0YQrTyV4_zo',
#   'plus_code': {'compound_code': 'HX23+8J 대한민국 서울특별시',
#    'global_code': '8Q98HX23+8J'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울영등포경찰서',
#   'address_components': [{'long_name': '608',
#     'short_name': '608',
#     'types': ['premise']},
#    {'long_name': '국회대로',
#     'short_name': '국회대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '영등포구',
#     'short_name': '영등포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '150-043',
#     'short_name': '150-043',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 영등포구 국회대로 608',
#   'geometry': {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5273930802915,
#      'lng': 126.9021580802915},
#     'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ1TimJLaffDURptXOs0Tj6sY',
#   'plus_code': {'compound_code': 'GWG2+C8 대한민국 서울특별시',
#    'global_code': '8Q98GWG2+C8'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울성동경찰서',
#   'address_components': [{'long_name': '9',
#     'short_name': '9',
#     'types': ['premise']},
#    {'long_name': '왕십리광장로',
#     'short_name': '왕십리광장로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '성동구',
#     'short_name': '성동구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '04750', 'short_name': '04750', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 성동구 왕십리광장로 9',
#   'geometry': {'location': {'lat': 37.56169149999999, 'lng': 127.0363006},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.56304048029149,
#      'lng': 127.0376495802915},
#     'southwest': {'lat': 37.5603425197085, 'lng': 127.0349516197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJA8Pio1mjfDURAN4B7oLFW4E',
#   'plus_code': {'compound_code': 'H26P+MG 대한민국 서울특별시',
#    'global_code': '8Q99H26P+MG'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울동작경찰서',
#   'address_components': [{'long_name': '148',
#     'short_name': '148',
#     'types': ['premise']},
#    {'long_name': '노량진로',
#     'short_name': '노량진로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '동작구',
#     'short_name': '동작구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '06902', 'short_name': '06902', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 동작구 노량진로 148',
#   'geometry': {'location': {'lat': 37.5130866, 'lng': 126.9428498},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5144355802915,
#      'lng': 126.9441987802915},
#     'southwest': {'lat': 37.51173761970851, 'lng': 126.9415008197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJB3ImbmiffDUR7BOlDuasX44',
#   'plus_code': {'compound_code': 'GW7V+64 대한민국 서울특별시',
#    'global_code': '8Q98GW7V+64'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울광진경찰서',
#   'address_components': [{'long_name': '167',
#     'short_name': '167',
#     'types': ['premise']},
#    {'long_name': '자양로',
#     'short_name': '자양로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '광진구',
#     'short_name': '광진구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '05024', 'short_name': '05024', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 광진구 자양로 167',
#   'geometry': {'location': {'lat': 37.5428231, 'lng': 127.0838395},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5441720802915,
#      'lng': 127.0851884802915},
#     'southwest': {'lat': 37.5414741197085, 'lng': 127.0824905197085}}},
#   'place_id': 'ChIJNbvWaSelfDURIjHmxaVUnBA',
#   'plus_code': {'compound_code': 'G3VM+4G 대한민국 서울특별시',
#    'global_code': '8Q99G3VM+4G'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울서부경찰서',
#   'address_components': [{'long_name': '58',
#     'short_name': '58',
#     'types': ['premise']},
#    {'long_name': '진흥로',
#     'short_name': '진흥로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '은평구',
#     'short_name': '은평구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '03458', 'short_name': '03458', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 은평구 진흥로 58',
#   'geometry': {'location': {'lat': 37.6020914, 'lng': 126.9213528},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.6034403802915,
#      'lng': 126.9227017802915},
#     'southwest': {'lat': 37.6007424197085, 'lng': 126.9200038197085}}},
#   'place_id': 'ChIJv6JEmDCYfDUR_RfmrfxsE-A',
#   'plus_code': {'compound_code': 'JW2C+RG 대한민국 서울특별시',
#    'global_code': '8Q98JW2C+RG'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울강북경찰서',
#   'address_components': [{'long_name': '406',
#     'short_name': '406',
#     'types': ['premise']},
#    {'long_name': '오패산로',
#     'short_name': '오패산로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '강북구',
#     'short_name': '강북구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '01062', 'short_name': '01062', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강북구 오패산로 406',
#   'geometry': {'location': {'lat': 37.63719740000001, 'lng': 127.0273048},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.63854638029151,
#      'lng': 127.0286537802915},
#     'southwest': {'lat': 37.63584841970851, 'lng': 127.0259558197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ_wkrvRG8fDURn_RnVb8f8tM',
#   'plus_code': {'compound_code': 'J2PG+VW 대한민국 서울특별시',
#    'global_code': '8Q99J2PG+VW'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울금천경찰서',
#   'address_components': [{'long_name': '50',
#     'short_name': '50',
#     'types': ['premise']},
#    {'long_name': '시흥대로73길',
#     'short_name': '시흥대로73길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '금천구',
#     'short_name': '금천구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '08611', 'short_name': '08611', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 금천구 시흥대로73길 50',
#   'geometry': {'location': {'lat': 37.4568129, 'lng': 126.8968061},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.45816188029149,
#      'lng': 126.8981550802915},
#     'southwest': {'lat': 37.45546391970849, 'lng': 126.8954571197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ2-RavjKefDURmXUg-JJ7fwk',
#   'plus_code': {'compound_code': 'FV4W+PP 대한민국 서울특별시',
#    'global_code': '8Q98FV4W+PP'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울남대문경찰서',
#   'address_components': [{'long_name': '410',
#     'short_name': '410',
#     'types': ['premise']},
#    {'long_name': '한강대로',
#     'short_name': '한강대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '04637', 'short_name': '04637', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 한강대로 410',
#   'geometry': {'location': {'lat': 37.5547584, 'lng': 126.9734981},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5561073802915,
#      'lng': 126.9748470802915},
#     'southwest': {'lat': 37.5534094197085, 'lng': 126.9721491197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJFXNA0GCifDURCtV185R5xD8',
#   'plus_code': {'compound_code': 'HX3F+W9 대한민국 서울특별시',
#    'global_code': '8Q98HX3F+W9'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울중랑경찰서',
#   'address_components': [{'long_name': '249-2',
#     'short_name': '249-2',
#     'types': ['premise']},
#    {'long_name': '묵제2동',
#     'short_name': '묵제2동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '중랑구',
#     'short_name': '중랑구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '02012', 'short_name': '02012', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중랑구 묵제2동 249-2',
#   'geometry': {'location': {'lat': 37.6056429, 'lng': 127.0764866},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.6069918802915,
#      'lng': 127.0778355802915},
#     'southwest': {'lat': 37.6042939197085, 'lng': 127.0751376197085}}},
#   'place_id': 'ChIJhVFglLG7fDURO6h1Z_2_yy4',
#   'plus_code': {'compound_code': 'J34G+7H 대한민국 서울특별시',
#    'global_code': '8Q99J34G+7H'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울강남경찰서',
#   'address_components': [{'long_name': '11',
#     'short_name': '11',
#     'types': ['premise']},
#    {'long_name': '테헤란로114길',
#     'short_name': '테헤란로114길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '강남구',
#     'short_name': '강남구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '06175', 'short_name': '06175', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강남구 테헤란로114길 11',
#   'geometry': {'location': {'lat': 37.5094352, 'lng': 127.0669578},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5107841802915,
#      'lng': 127.0683067802915},
#     'southwest': {'lat': 37.5080862197085, 'lng': 127.0656088197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJcbaB0UakfDURoyy8orQOWFg',
#   'plus_code': {'compound_code': 'G358+QQ 대한민국 서울특별시',
#    'global_code': '8Q99G358+QQ'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울강서경찰서',
#   'address_components': [{'long_name': '308',
#     'short_name': '308',
#     'types': ['premise']},
#    {'long_name': '화곡로',
#     'short_name': '화곡로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '강서구',
#     'short_name': '강서구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '07658', 'short_name': '07658', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강서구 화곡로 308',
#   'geometry': {'location': {'lat': 37.5513622, 'lng': 126.8502799},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5527111802915,
#      'lng': 126.8516288802915},
#     'southwest': {'lat': 37.5500132197085, 'lng': 126.8489309197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJc__1RmCdfDUR7s7NK4_p308',
#   'plus_code': {'compound_code': 'HV22+G4 대한민국 서울특별시',
#    'global_code': '8Q98HV22+G4'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울강동경찰서',
#   'address_components': [{'long_name': '57',
#     'short_name': '57',
#     'types': ['premise']},
#    {'long_name': '성내로',
#     'short_name': '성내로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '강동구',
#     'short_name': '강동구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '05397', 'short_name': '05397', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강동구 성내로 57',
#   'geometry': {'location': {'lat': 37.528511, 'lng': 127.1268224},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5298599802915,
#      'lng': 127.1281713802915},
#     'southwest': {'lat': 37.52716201970851, 'lng': 127.1254734197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJz_fwQlilfDURUxRjmop7l7s',
#   'plus_code': {'compound_code': 'G4HG+CP 대한민국 서울특별시',
#    'global_code': '8Q99G4HG+CP'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울종암경찰서',
#   'address_components': [{'long_name': '32',
#     'short_name': '32',
#     'types': ['premise']},
#    {'long_name': '화랑로7길',
#     'short_name': '화랑로7길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '성북구',
#     'short_name': '성북구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '02751', 'short_name': '02751', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 성북구 화랑로7길 32',
#   'geometry': {'location': {'lat': 37.603989, 'lng': 127.039937},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.60533798029149,
#      'lng': 127.0412859802915},
#     'southwest': {'lat': 37.6026400197085, 'lng': 127.0385880197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJgbcSB7i7fDURlbUEBi_bHEw',
#   'plus_code': {'compound_code': 'J23Q+HX 대한민국 서울특별시',
#    'global_code': '8Q99J23Q+HX'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울구로경찰서',
#   'address_components': [{'long_name': '5층',
#     'short_name': '5층',
#     'types': ['subpremise']},
#    {'long_name': '신도림테크노마트',
#     'short_name': '신도림테크노마트',
#     'types': ['establishment', 'point_of_interest']},
#    {'long_name': '97', 'short_name': '97', 'types': ['premise']},
#    {'long_name': '새말로',
#     'short_name': '새말로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '구로구',
#     'short_name': '구로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '08288', 'short_name': '08288', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 구로구 새말로 97 신도림테크노마트 5층',
#   'geometry': {'location': {'lat': 37.5074418, 'lng': 126.8902237},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.50879078029149,
#      'lng': 126.8915726802915},
#     'southwest': {'lat': 37.50609281970849, 'lng': 126.8888747197085}}},
#   'place_id': 'ChIJmRBVTBSefDURMQeUuNnWXlU',
#   'plus_code': {'compound_code': 'GV4R+X3 대한민국 서울특별시',
#    'global_code': '8Q98GV4R+X3'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울서초경찰서',
#   'address_components': [{'long_name': '179',
#     'short_name': '179',
#     'types': ['premise']},
#    {'long_name': '반포대로',
#     'short_name': '반포대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '서초구',
#     'short_name': '서초구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '06590', 'short_name': '06590', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서초구 반포대로 179',
#   'geometry': {'location': {'lat': 37.4954676, 'lng': 127.0053395},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.49681658029149,
#      'lng': 127.0066884802915},
#     'southwest': {'lat': 37.4941186197085, 'lng': 127.0039905197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJWffyGkqhfDURLuilSJqwZLA',
#   'plus_code': {'compound_code': 'F2W4+54 대한민국 서울특별시',
#    'global_code': '8Q99F2W4+54'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울양천경찰서',
#   'address_components': [{'long_name': '99',
#     'short_name': '99',
#     'types': ['premise']},
#    {'long_name': '목동동로',
#     'short_name': '목동동로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '양천구',
#     'short_name': '양천구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '08095', 'short_name': '08095', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 양천구 목동동로 99',
#   'geometry': {'location': {'lat': 37.5167711, 'lng': 126.8656996},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5181200802915,
#      'lng': 126.8670485802915},
#     'southwest': {'lat': 37.5154221197085, 'lng': 126.8643506197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJwfQIp9edfDURwNXXjbRynKo',
#   'plus_code': {'compound_code': 'GV88+P7 대한민국 서울특별시',
#    'global_code': '8Q98GV88+P7'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울관악경찰서',
#   'address_components': [{'long_name': '33',
#     'short_name': '33',
#     'types': ['premise']},
#    {'long_name': '관악로5길',
#     'short_name': '관악로5길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '관악구',
#     'short_name': '관악구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '08833', 'short_name': '08833', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 관악구 관악로5길 33',
#   'geometry': {'location': {'lat': 37.4743945, 'lng': 126.9513489},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.47574348029149,
#      'lng': 126.9526978802915},
#     'southwest': {'lat': 37.47304551970849, 'lng': 126.9499999197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJIcPY0_SffDURRUZI3LvvKiU',
#   'plus_code': {'compound_code': 'FXF2+QG 대한민국 서울특별시',
#    'global_code': '8Q98FXF2+QG'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울송파경찰서',
#   'address_components': [{'long_name': '221',
#     'short_name': '221',
#     'types': ['premise']},
#    {'long_name': '중대로',
#     'short_name': '중대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '송파구',
#     'short_name': '송파구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 송파구 중대로 221',
#   'geometry': {'location': {'lat': 37.5019044, 'lng': 127.1271338},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5032533802915,
#      'lng': 127.1284827802915},
#     'southwest': {'lat': 37.5005554197085, 'lng': 127.1257848197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJA1pC63-vfDURYsWgKqV9nUw',
#   'plus_code': {'compound_code': 'G42G+QV 대한민국 서울특별시',
#    'global_code': '8Q99G42G+QV'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울방배경찰서',
#   'address_components': [{'long_name': '204',
#     'short_name': '204',
#     'types': ['premise']},
#    {'long_name': '동작대로',
#     'short_name': '동작대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '서초구',
#     'short_name': '서초구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '06555', 'short_name': '06555', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서초구 동작대로 204',
#   'geometry': {'location': {'lat': 37.4945959, 'lng': 126.9831279},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4959448802915,
#      'lng': 126.9844768802915},
#     'southwest': {'lat': 37.4932469197085, 'lng': 126.9817789197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJIVym0kygfDUR9S_sSnCasQU',
#   'plus_code': {'compound_code': 'FXVM+R7 대한민국 서울특별시',
#    'global_code': '8Q98FXVM+R7'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울은평경찰서',
#   'address_components': [{'long_name': '365',
#     'short_name': '365',
#     'types': ['premise']},
#    {'long_name': '연서로',
#     'short_name': '연서로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '은평구',
#     'short_name': '은평구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '03338', 'short_name': '03338', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 은평구 연서로 365',
#   'geometry': {'location': {'lat': 37.6280204, 'lng': 126.9287899},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.6293693802915,
#      'lng': 126.9301388802915},
#     'southwest': {'lat': 37.6266714197085, 'lng': 126.9274409197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJH8IMtZWXfDURVy-L5JUjvM4',
#   'plus_code': {'compound_code': 'JWHH+6G 대한민국 서울특별시',
#    'global_code': '8Q98JWHH+6G'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울도봉경찰서',
#   'address_components': [{'long_name': '403',
#     'short_name': '403',
#     'types': ['premise']},
#    {'long_name': '노해로',
#     'short_name': '노해로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '도봉구',
#     'short_name': '도봉구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 도봉구 노해로 403',
#   'geometry': {'location': {'lat': 37.6533589, 'lng': 127.052682},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.6547078802915,
#      'lng': 127.0540309802915},
#     'southwest': {'lat': 37.6520099197085, 'lng': 127.0513330197085}}},
#   'place_id': 'ChIJTUiMyEW5fDURH_6VenyTTpw',
#   'plus_code': {'compound_code': 'M333+83 대한민국 서울특별시',
#    'global_code': '8Q99M333+83'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울동대문경찰서',
#   'address_components': [{'long_name': '29',
#     'short_name': '29',
#     'types': ['premise']},
#    {'long_name': '약령시로21길',
#     'short_name': '약령시로21길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '동대문구',
#     'short_name': '동대문구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '02486', 'short_name': '02486', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 동대문구 약령시로21길 29',
#   'geometry': {'location': {'lat': 37.58506149999999, 'lng': 127.0457679},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5864104802915,
#      'lng': 127.0471168802915},
#     'southwest': {'lat': 37.5837125197085, 'lng': 127.0444189197085}}},
#   'place_id': 'ChIJKUctL1y7fDURClHzlLM2Ir8',
#   'plus_code': {'compound_code': 'H2PW+28 대한민국 서울특별시',
#    'global_code': '8Q99H2PW+28'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'police_name': '서울수서경찰서',
#   'address_components': [{'long_name': '617',
#     'short_name': '617',
#     'types': ['premise']},
#    {'long_name': '개포로',
#     'short_name': '개포로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '강남구',
#     'short_name': '강남구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '06336', 'short_name': '06336', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강남구 개포로 617',
#   'geometry': {'location': {'lat': 37.49349, 'lng': 127.0772119},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4948389802915,
#      'lng': 127.0785608802915},
#     'southwest': {'lat': 37.49214101970851, 'lng': 127.0758629197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJY2ee_TGkfDURAWUtC8jBHag',
#   'plus_code': {'compound_code': 'F3VG+9V 대한민국 서울특별시',
#    'global_code': '8Q99F3VG+9V'},
#   'types': ['establishment', 'point_of_interest']}]

# %%
data[0]
# Out:
# {'police_name': '서울종로경찰서',
#  'address_components': [{'long_name': '41',
#    'short_name': '41',
#    'types': ['premise']},
#   {'long_name': '인사동5길',
#    'short_name': '인사동5길',
#    'types': ['political', 'sublocality', 'sublocality_level_4']},
#   {'long_name': '종로구',
#    'short_name': '종로구',
#    'types': ['political', 'sublocality', 'sublocality_level_1']},
#   {'long_name': '서울특별시',
#    'short_name': '서울특별시',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': '대한민국', 'short_name': 'KR', 'types': ['country', 'political']},
#   {'long_name': '110-160', 'short_name': '110-160', 'types': ['postal_code']}],
#  'formatted_address': '대한민국 서울특별시 종로구 인사동5길 41',
#  'geometry': {'location': {'lat': 37.571824, 'lng': 126.9841533},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 37.5731729802915,
#     'lng': 126.9855022802915},
#    'southwest': {'lat': 37.5704750197085, 'lng': 126.9828043197085}}},
#  'partial_match': True,
#  'place_id': 'ChIJRVgVHsOifDURFhKFchVo22I',
#  'plus_code': {'compound_code': 'HXCM+PM 대한민국 서울특별시',
#   'global_code': '8Q98HXCM+PM'},
#  'types': ['establishment', 'point_of_interest', 'police']}

# %%
data[0].keys()
# Out:
# dict_keys(['police_name', 'address_components', 'formatted_address', 'geometry', 'partial_match', 'place_id', 'plus_code', 'types'])

# %%
data[0]["address_components"]
# Out:
# [{'long_name': '41', 'short_name': '41', 'types': ['premise']},
#  {'long_name': '인사동5길',
#   'short_name': '인사동5길',
#   'types': ['political', 'sublocality', 'sublocality_level_4']},
#  {'long_name': '종로구',
#   'short_name': '종로구',
#   'types': ['political', 'sublocality', 'sublocality_level_1']},
#  {'long_name': '서울특별시',
#   'short_name': '서울특별시',
#   'types': ['administrative_area_level_1', 'political']},
#  {'long_name': '대한민국', 'short_name': 'KR', 'types': ['country', 'political']},
#  {'long_name': '110-160', 'short_name': '110-160', 'types': ['postal_code']}]

# %%
# 경찰서 이름과 주소를 print해보자!

for i in data:
    print(i["police_name"], "-->", i["formatted_address"])
# Out:
# 서울종로경찰서 --> 대한민국 서울특별시 종로구 인사동5길 41
# 서울용산경찰서 --> 대한민국 서울특별시 용산구 백범로 329
# 서울서대문경찰서 --> 대한민국 서울특별시 서대문구 충정로 13
# 서울중부경찰서 --> 대한민국 서울특별시 중구 수표로 27
# 서울혜화경찰서 --> 대한민국 서울특별시 종로구 창경궁로 112-16
# 서울성북경찰서 --> 대한민국 서울특별시 성북구 보문로 170
# 서울노원경찰서 --> 대한민국 서울특별시 노원경찰서
# 서울마포경찰서 --> 대한민국 서울특별시 마포구 마포대로 183
# 서울영등포경찰서 --> 대한민국 서울특별시 영등포구 국회대로 608
# 서울성동경찰서 --> 대한민국 서울특별시 성동구 왕십리광장로 9
# 서울동작경찰서 --> 대한민국 서울특별시 동작구 노량진로 148
# 서울광진경찰서 --> 대한민국 서울특별시 광진구 자양로 167
# 서울서부경찰서 --> 대한민국 서울특별시 은평구 진흥로 58
# 서울강북경찰서 --> 대한민국 서울특별시 강북구 오패산로 406
# 서울금천경찰서 --> 대한민국 서울특별시 금천구 시흥대로73길 50
# 서울남대문경찰서 --> 대한민국 서울특별시 중구 한강대로 410
# 서울중랑경찰서 --> 대한민국 서울특별시 중랑구 묵제2동 249-2
# 서울강남경찰서 --> 대한민국 서울특별시 강남구 테헤란로114길 11
# 서울강서경찰서 --> 대한민국 서울특별시 강서구 화곡로 308
# 서울강동경찰서 --> 대한민국 서울특별시 강동구 성내로 57
# 서울종암경찰서 --> 대한민국 서울특별시 성북구 화랑로7길 32
# 서울구로경찰서 --> 대한민국 서울특별시 구로구 새말로 97 신도림테크노마트 5층
# 서울서초경찰서 --> 대한민국 서울특별시 서초구 반포대로 179
# 서울양천경찰서 --> 대한민국 서울특별시 양천구 목동동로 99
# 서울관악경찰서 --> 대한민국 서울특별시 관악구 관악로5길 33
# 서울송파경찰서 --> 대한민국 서울특별시 송파구 중대로 221
# 서울방배경찰서 --> 대한민국 서울특별시 서초구 동작대로 204
# 서울은평경찰서 --> 대한민국 서울특별시 은평구 연서로 365
# 서울도봉경찰서 --> 대한민국 서울특별시 도봉구 노해로 403
# 서울동대문경찰서 --> 대한민국 서울특별시 동대문구 약령시로21길 29
# 서울수서경찰서 --> 대한민국 서울특별시 강남구 개포로 617

# %%
data[0]["geometry"]
# Out:
# {'location': {'lat': 37.571824, 'lng': 126.9841533},
#  'location_type': 'ROOFTOP',
#  'viewport': {'northeast': {'lat': 37.5731729802915, 'lng': 126.9855022802915},
#   'southwest': {'lat': 37.5704750197085, 'lng': 126.9828043197085}}}

# %%
data[0]["geometry"]["location"]["lat"]
# Out:
# 37.571824

# %%
# json의 정보를 dataframe으로 만들어 보자

police_info_list = []

for i in data:
    inner_dict = {}
    inner_dict["police_name"] = i["police_name"]
    inner_dict["address"] = i["formatted_address"]
    inner_dict["lat"] = i["geometry"]["location"]["lat"]
    inner_dict["lng"] = i["geometry"]["location"]["lng"]
    inner_dict["gu"] = i["formatted_address"].split(" ")[2]
    
    police_info_list.append(inner_dict)

# %%
police_info_list
# Out:
# [{'police_name': '서울종로경찰서',
#   'address': '대한민국 서울특별시 종로구 인사동5길 41',
#   'lat': 37.571824,
#   'lng': 126.9841533,
#   'gu': '종로구'},
#  {'police_name': '서울용산경찰서',
#   'address': '대한민국 서울특별시 용산구 백범로 329',
#   'lat': 37.5387099,
#   'lng': 126.9659183,
#   'gu': '용산구'},
#  {'police_name': '서울서대문경찰서',
#   'address': '대한민국 서울특별시 서대문구 충정로 13',
#   'lat': 37.560607,
#   'lng': 126.9626106,
#   'gu': '서대문구'},
#  {'police_name': '서울중부경찰서',
#   'address': '대한민국 서울특별시 중구 수표로 27',
#   'lat': 37.56361709999999,
#   'lng': 126.9896517,
#   'gu': '중구'},
#  {'police_name': '서울혜화경찰서',
#   'address': '대한민국 서울특별시 종로구 창경궁로 112-16',
#   'lat': 37.5719679,
#   'lng': 126.9989574,
#   'gu': '종로구'},
#  {'police_name': '서울성북경찰서',
#   'address': '대한민국 서울특별시 성북구 보문로 170',
#   'lat': 37.5898228,
#   'lng': 127.0163427,
#   'gu': '성북구'},
#  {'police_name': '서울노원경찰서',
#   'address': '대한민국 서울특별시 노원경찰서',
#   'lat': 37.641836,
#   'lng': 127.072198,
#   'gu': '노원경찰서'},
#  {'police_name': '서울마포경찰서',
#   'address': '대한민국 서울특별시 마포구 마포대로 183',
#   'lat': 37.550814,
#   'lng': 126.954028,
#   'gu': '마포구'},
#  {'police_name': '서울영등포경찰서',
#   'address': '대한민국 서울특별시 영등포구 국회대로 608',
#   'lat': 37.5260441,
#   'lng': 126.9008091,
#   'gu': '영등포구'},
#  {'police_name': '서울성동경찰서',
#   'address': '대한민국 서울특별시 성동구 왕십리광장로 9',
#   'lat': 37.56169149999999,
#   'lng': 127.0363006,
#   'gu': '성동구'},
#  {'police_name': '서울동작경찰서',
#   'address': '대한민국 서울특별시 동작구 노량진로 148',
#   'lat': 37.5130866,
#   'lng': 126.9428498,
#   'gu': '동작구'},
#  {'police_name': '서울광진경찰서',
#   'address': '대한민국 서울특별시 광진구 자양로 167',
#   'lat': 37.5428231,
#   'lng': 127.0838395,
#   'gu': '광진구'},
#  {'police_name': '서울서부경찰서',
#   'address': '대한민국 서울특별시 은평구 진흥로 58',
#   'lat': 37.6020914,
#   'lng': 126.9213528,
#   'gu': '은평구'},
#  {'police_name': '서울강북경찰서',
#   'address': '대한민국 서울특별시 강북구 오패산로 406',
#   'lat': 37.63719740000001,
#   'lng': 127.0273048,
#   'gu': '강북구'},
#  {'police_name': '서울금천경찰서',
#   'address': '대한민국 서울특별시 금천구 시흥대로73길 50',
#   'lat': 37.4568129,
#   'lng': 126.8968061,
#   'gu': '금천구'},
#  {'police_name': '서울남대문경찰서',
#   'address': '대한민국 서울특별시 중구 한강대로 410',
#   'lat': 37.5547584,
#   'lng': 126.9734981,
#   'gu': '중구'},
#  {'police_name': '서울중랑경찰서',
#   'address': '대한민국 서울특별시 중랑구 묵제2동 249-2',
#   'lat': 37.6056429,
#   'lng': 127.0764866,
#   'gu': '중랑구'},
#  {'police_name': '서울강남경찰서',
#   'address': '대한민국 서울특별시 강남구 테헤란로114길 11',
#   'lat': 37.5094352,
#   'lng': 127.0669578,
#   'gu': '강남구'},
#  {'police_name': '서울강서경찰서',
#   'address': '대한민국 서울특별시 강서구 화곡로 308',
#   'lat': 37.5513622,
#   'lng': 126.8502799,
#   'gu': '강서구'},
#  {'police_name': '서울강동경찰서',
#   'address': '대한민국 서울특별시 강동구 성내로 57',
#   'lat': 37.528511,
#   'lng': 127.1268224,
#   'gu': '강동구'},
#  {'police_name': '서울종암경찰서',
#   'address': '대한민국 서울특별시 성북구 화랑로7길 32',
#   'lat': 37.603989,
#   'lng': 127.039937,
#   'gu': '성북구'},
#  {'police_name': '서울구로경찰서',
#   'address': '대한민국 서울특별시 구로구 새말로 97 신도림테크노마트 5층',
#   'lat': 37.5074418,
#   'lng': 126.8902237,
#   'gu': '구로구'},
#  {'police_name': '서울서초경찰서',
#   'address': '대한민국 서울특별시 서초구 반포대로 179',
#   'lat': 37.4954676,
#   'lng': 127.0053395,
#   'gu': '서초구'},
#  {'police_name': '서울양천경찰서',
#   'address': '대한민국 서울특별시 양천구 목동동로 99',
#   'lat': 37.5167711,
#   'lng': 126.8656996,
#   'gu': '양천구'},
#  {'police_name': '서울관악경찰서',
#   'address': '대한민국 서울특별시 관악구 관악로5길 33',
#   'lat': 37.4743945,
#   'lng': 126.9513489,
#   'gu': '관악구'},
#  {'police_name': '서울송파경찰서',
#   'address': '대한민국 서울특별시 송파구 중대로 221',
#   'lat': 37.5019044,
#   'lng': 127.1271338,
#   'gu': '송파구'},
#  {'police_name': '서울방배경찰서',
#   'address': '대한민국 서울특별시 서초구 동작대로 204',
#   'lat': 37.4945959,
#   'lng': 126.9831279,
#   'gu': '서초구'},
#  {'police_name': '서울은평경찰서',
#   'address': '대한민국 서울특별시 은평구 연서로 365',
#   'lat': 37.6280204,
#   'lng': 126.9287899,
#   'gu': '은평구'},
#  {'police_name': '서울도봉경찰서',
#   'address': '대한민국 서울특별시 도봉구 노해로 403',
#   'lat': 37.6533589,
#   'lng': 127.052682,
#   'gu': '도봉구'},
#  {'police_name': '서울동대문경찰서',
#   'address': '대한민국 서울특별시 동대문구 약령시로21길 29',
#   'lat': 37.58506149999999,
#   'lng': 127.0457679,
#   'gu': '동대문구'},
#  {'police_name': '서울수서경찰서',
#   'address': '대한민국 서울특별시 강남구 개포로 617',
#   'lat': 37.49349,
#   'lng': 127.0772119,
#   'gu': '강남구'}]

# %%
df_police = pd.DataFrame(data = police_info_list)
df_police.loc[5:10]
# Out:
#    police_name                   address        lat         lng     gu
# 5      서울성북경찰서    대한민국 서울특별시 성북구 보문로 170  37.589823  127.016343    성북구
# 6      서울노원경찰서          대한민국 서울특별시 노원경찰서  37.641836  127.072198  노원경찰서
# 7      서울마포경찰서   대한민국 서울특별시 마포구 마포대로 183  37.550814  126.954028    마포구
# 8     서울영등포경찰서  대한민국 서울특별시 영등포구 국회대로 608  37.526044  126.900809   영등포구
# 9      서울성동경찰서   대한민국 서울특별시 성동구 왕십리광장로 9  37.561691  127.036301    성동구
# 10     서울동작경찰서   대한민국 서울특별시 동작구 노량진로 148  37.513087  126.942850    동작구

# %%
df_police.loc[6, "gu"] = "노원구"

# %% [markdown]
# # 6. 데이터 병합: merge

# %%
#crime에 관서명을 바꿔보자

station_name = []

for name in crime.index:
    station_name.append("서울" + str(name[:-1]) + "경찰서")

crime["police_name"] = station_name

# %%
crime
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 관서명
# 중부서       2      2      3      2    105     65   1395    477   1355   1170
# 종로서       3      3      6      5    115     98   1070    413   1278   1070
# 남대문서      1      0      6      4     65     46   1153    382    869    794
# 서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 혜화서       3      2      5      4     96     63   1114    424   1015    861
# 용산서       5      5     14     14    194    173   1557    587   2050   1704
# 성북서       2      2      2      1     86     71    953    409   1194   1015
# 동대문서      5      5     13     13    173    146   1981    814   2548   2227
# 마포서       8      8     14     10    294    247   2555    813   2983   2519
# 영등포서     14     12     22     20    295    183   2964    978   3572   2961
# 성동서       4      4      9      8    126    119   1607    597   1612   1395
# 동작서       5      5      9      5    285    139   1865    661   1910   1587
# 광진서       4      4     14     26    240    220   3026   1277   2625   2180
# 서부서       2      2      2      1     70     59    819    293   1192   1038
# 강북서       7      8     14     13    153    126   1434    618   2649   2348
# 중랑서      13     12     11      9    187    148   2135    829   2847   2407
# 강남서       3      3     15     12    300    225   2411    984   2465   2146
# 관악서       9      8     12     14    320    221   2706    827   3298   2642
# 강서서       7      8     13     13    262    191   2096   1260   3207   2718
# 강동서       4      3      6      8    156    123   2366    789   2712   2248
# 종암서       3      3      3      3     64     53    832    332   1015    840
# 구로서       8      6     15     11    281    164   2335    889   3007   2432
# 서초서       7      4      8      5    334    193   1982    905   1852   1607
# 양천서       3      5      6      3    120    105   1890    672   2509   2030
# 송파서      11     10     13     10    220    178   3239   1129   3295   2786
# 노원서      10     10      7      7    197    121   2193    801   2723   2329
# 방배서       1      2      1      1     59     56    653    186    547    491
# 도봉서       3      3      9     10    102    106   1063    478   1487   1303
# 수서서      10      7      6      6    149    124   1439    666   1819   1559
#
#       total  occurs_total  arrest_total police_name
# 관서명
# 중부서    4576          2860          1716     서울중부경찰서
# 종로서    4061          2472          1589     서울종로경찰서
# 남대문서   3320          2094          1226    서울남대문경찰서
# 서대문서   6608          4029          2579    서울서대문경찰서
# 혜화서    3587          2233          1354     서울혜화경찰서
# 용산서    6303          3820          2483     서울용산경찰서
# 성북서    3735          2237          1498     서울성북경찰서
# 동대문서   7925          4720          3205    서울동대문경찰서
# 마포서    9451          5854          3597     서울마포경찰서
# 영등포서  11021          6867          4154    서울영등포경찰서
# 성동서    5481          3358          2123     서울성동경찰서
# 동작서    6471          4074          2397     서울동작경찰서
# 광진서    9616          5909          3707     서울광진경찰서
# 서부서    3478          2085          1393     서울서부경찰서
# 강북서    7370          4257          3113     서울강북경찰서
# 중랑서    8598          5193          3405     서울중랑경찰서
# 강남서    8564          5194          3370     서울강남경찰서
# 관악서   10057          6345          3712     서울관악경찰서
# 강서서    9775          5585          4190     서울강서경찰서
# 강동서    8415          5244          3171     서울강동경찰서
# 종암서    3148          1917          1231     서울종암경찰서
# 구로서    9148          5646          3502     서울구로경찰서
# 서초서    6897          4183          2714     서울서초경찰서
# 양천서    7343          4528          2815     서울양천경찰서
# 송파서   10891          6778          4113     서울송파경찰서
# 노원서    8398          5130          3268     서울노원경찰서
# 방배서    1997          1261           736     서울방배경찰서
# 도봉서    4564          2664          1900     서울도봉경찰서
# 수서서    5785          3423          2362     서울수서경찰서

# %% [markdown]
# * `pd.merge(df_left, df_right, how='inner', on=None)`이 default
# * `on=None`이면 `how='inner'` 이므로 두 데이터의 공통 feature namer을 기준으로 inner join
# * `how='outer'`로 하고 `on="feature name"`으로 하면 feature namer을 기준으로 outer join. 빈 값은 `NaN`으로 채운다
# * 공통의 feature name이 없는 경우 왼쪽(`left_on = "left feature name"`), 오른쪽(`right_on = "right feature name"`)에서 기준으로 할 feature name을 지정해 줄 수 있다.
# * index를 기준으로 병합할 수도 있다.

# %%
crime_police_inner = pd.merge(left = crime, 
                        right = df_police,
                        how='inner', 
                        on=None)

# %%
crime_police_inner.shape
# Out:
# (29, 18)

# %%
crime_police_outer = pd.merge(left = crime, 
                        right = df_police,
                        how='outer', 
                        on="police_name")

# %%
crime_police_outer.shape
# Out:
# (31, 18)

# %%
crime_police_outer
# Out:
#     살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거   절도 발생   절도 검거   폭력 발생   폭력 검거  \
# 0     2.0    2.0    3.0    2.0  105.0   65.0  1395.0   477.0  1355.0  1170.0
# 1     3.0    3.0    6.0    5.0  115.0   98.0  1070.0   413.0  1278.0  1070.0
# 2     1.0    0.0    6.0    4.0   65.0   46.0  1153.0   382.0   869.0   794.0
# 3     2.0    2.0    5.0    4.0  154.0  124.0  1812.0   738.0  2056.0  1711.0
# 4     3.0    2.0    5.0    4.0   96.0   63.0  1114.0   424.0  1015.0   861.0
# 5     5.0    5.0   14.0   14.0  194.0  173.0  1557.0   587.0  2050.0  1704.0
# 6     2.0    2.0    2.0    1.0   86.0   71.0   953.0   409.0  1194.0  1015.0
# 7     5.0    5.0   13.0   13.0  173.0  146.0  1981.0   814.0  2548.0  2227.0
# 8     8.0    8.0   14.0   10.0  294.0  247.0  2555.0   813.0  2983.0  2519.0
# 9    14.0   12.0   22.0   20.0  295.0  183.0  2964.0   978.0  3572.0  2961.0
# 10    4.0    4.0    9.0    8.0  126.0  119.0  1607.0   597.0  1612.0  1395.0
# 11    5.0    5.0    9.0    5.0  285.0  139.0  1865.0   661.0  1910.0  1587.0
# 12    4.0    4.0   14.0   26.0  240.0  220.0  3026.0  1277.0  2625.0  2180.0
# 13    2.0    2.0    2.0    1.0   70.0   59.0   819.0   293.0  1192.0  1038.0
# 14    7.0    8.0   14.0   13.0  153.0  126.0  1434.0   618.0  2649.0  2348.0
# 15   13.0   12.0   11.0    9.0  187.0  148.0  2135.0   829.0  2847.0  2407.0
# 16    3.0    3.0   15.0   12.0  300.0  225.0  2411.0   984.0  2465.0  2146.0
# 17    9.0    8.0   12.0   14.0  320.0  221.0  2706.0   827.0  3298.0  2642.0
# 18    7.0    8.0   13.0   13.0  262.0  191.0  2096.0  1260.0  3207.0  2718.0
# 19    4.0    3.0    6.0    8.0  156.0  123.0  2366.0   789.0  2712.0  2248.0
# 20    3.0    3.0    3.0    3.0   64.0   53.0   832.0   332.0  1015.0   840.0
# 21    8.0    6.0   15.0   11.0  281.0  164.0  2335.0   889.0  3007.0  2432.0
# 22    7.0    4.0    8.0    5.0  334.0  193.0  1982.0   905.0  1852.0  1607.0
# 23    3.0    5.0    6.0    3.0  120.0  105.0  1890.0   672.0  2509.0  2030.0
# 24   11.0   10.0   13.0   10.0  220.0  178.0  3239.0  1129.0  3295.0  2786.0
# 25   10.0   10.0    7.0    7.0  197.0  121.0  2193.0   801.0  2723.0  2329.0
# 26    1.0    2.0    1.0    1.0   59.0   56.0   653.0   186.0   547.0   491.0
# 27    3.0    3.0    9.0   10.0  102.0  106.0  1063.0   478.0  1487.0  1303.0
# 28   10.0    7.0    6.0    6.0  149.0  124.0  1439.0   666.0  1819.0  1559.0
# 29    NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 11            대한민국 서울특별시 동작구 노량진로 148  37.513087  126.942850   동작구
# 12             대한민국 서울특별시 광진구 자양로 167  37.542823  127.083839   광진구
# 13              대한민국 서울특별시 은평구 진흥로 58  37.602091  126.921353   은평구
# 14            대한민국 서울특별시 강북구 오패산로 406  37.637197  127.027305   강북구
# 15          대한민국 서울특별시 중랑구 묵제2동 249-2  37.605643  127.076487   중랑구
# 16         대한민국 서울특별시 강남구 테헤란로114길 11  37.509435  127.066958   강남구
# 17            대한민국 서울특별시 관악구 관악로5길 33  37.474395  126.951349   관악구
# 18             대한민국 서울특별시 강서구 화곡로 308  37.551362  126.850280   강서구
# 19              대한민국 서울특별시 강동구 성내로 57  37.528511  127.126822   강동구
# 20            대한민국 서울특별시 성북구 화랑로7길 32  37.603989  127.039937   성북구
# 21  대한민국 서울특별시 구로구 새말로 97 신도림테크노마트 5층  37.507442  126.890224   구로구
# 22            대한민국 서울특별시 서초구 반포대로 179  37.495468  127.005340   서초구
# 23             대한민국 서울특별시 양천구 목동동로 99  37.516771  126.865700   양천구
# 24             대한민국 서울특별시 송파구 중대로 221  37.501904  127.127134   송파구
# 25                   대한민국 서울특별시 노원경찰서  37.641836  127.072198   노원구
# 26            대한민국 서울특별시 서초구 동작대로 204  37.494596  126.983128   서초구
# 27             대한민국 서울특별시 도봉구 노해로 403  37.653359  127.052682   도봉구
# 28             대한민국 서울특별시 강남구 개포로 617  37.493490  127.077212   강남구
# 29          대한민국 서울특별시 금천구 시흥대로73길 50  37.456813  126.896806   금천구
# 30             대한민국 서울특별시 은평구 연서로 365  37.628020  126.928790   은평구

# %%
crime_police_outer = crime_police_outer.fillna(0.0)

# %% [markdown]
# # 7. 지도 시각화

# %%
## 서울 이 중심에 오도록 folium을 이용하여 지도를 그리시오.

map = folium.Map(location=[37.58, 127.0], zoom_start=11)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_090b2011129cb5a47a197579db3512e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_090b2011129cb5a47a197579db3512e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_090b2011129cb5a47a197579db3512e3 = L.map(
#                 &quot;map_090b2011129cb5a47a197579db3512e3&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc703815ecc41db16fc3cf405a41a904 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc703815ecc41db16fc3cf405a41a904.addTo(map_090b2011129cb5a47a197579db3512e3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lat = crime_police_outer.loc[0]["lat"]
lng = crime_police_outer.loc[0]["lng"]
police_name = crime_police_outer.loc[0]["police_name"]
occurs_total = crime_police_outer.loc[0]["occurs_total"]

folium.Marker(location = [lat, lng],
              icon=folium.Icon(color='blue',icon='star'),
              popup=police_name).add_to(map)

folium.Circle(location = [lat, lng],
              radius = occurs_total/2,
              fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_090b2011129cb5a47a197579db3512e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_090b2011129cb5a47a197579db3512e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_090b2011129cb5a47a197579db3512e3 = L.map(
#                 &quot;map_090b2011129cb5a47a197579db3512e3&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc703815ecc41db16fc3cf405a41a904 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc703815ecc41db16fc3cf405a41a904.addTo(map_090b2011129cb5a47a197579db3512e3);
#
#
#             tile_layer_bc703815ecc41db16fc3cf405a41a904.addTo(map_090b2011129cb5a47a197579db3512e3);
#
#
#             var marker_4c4f6deb8cc69cf247b56315b3d48942 = L.marker(
#                 [37.56361709999999, 126.9896517],
#                 {}
#             ).addTo(map_090b2011129cb5a47a197579db3512e3);
#
#
#             var icon_7a0aa802edd777120374ca45bb9c93a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c4f6deb8cc69cf247b56315b3d48942.setIcon(icon_7a0aa802edd777120374ca45bb9c93a7);
#
#
#         var popup_ba722b7e73928614956375983f968040 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f5f606694cf565cdac91d8e818f18ee = $(`&lt;div id=&quot;html_5f5f606694cf565cdac91d8e818f18ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울중부경찰서&lt;/div&gt;`)[0];
#                 popup_ba722b7e73928614956375983f968040.setContent(html_5f5f606694cf565cdac91d8e818f18ee);
#
#
#
#         marker_4c4f6deb8cc69cf247b56315b3d48942.bindPopup(popup_ba722b7e73928614956375983f968040)
#         ;
#
#
#
#
#             var circle_ecce502eb822117af5da71652cb88d09 = L.circle(
#                 [37.56361709999999, 126.9896517],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1430.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_090b2011129cb5a47a197579db3512e3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i, j in crime_police_outer[:3].iterrows():
    print(i)
    print(j)
    print("===")
# Out:
# 0
# 살인 발생                            2.0
# 살인 검거                            2.0
# 강도 발생                            3.0
# 강도 검거                            2.0
# 강간 발생                          105.0
# 강간 검거                           65.0
# 절도 발생                         1395.0
# 절도 검거                          477.0
# 폭력 발생                         1355.0
# 폭력 검거                         1170.0
# total                         4576.0
# occurs_total                  2860.0
# arrest_total                  1716.0
# police_name                  서울중부경찰서
# address         대한민국 서울특별시 중구 수표로 27
# lat                        37.563617
# lng                       126.989652
# gu                                중구
# Name: 0, dtype: object
# ===
# 1
# 살인 발생                               3.0
# 살인 검거                               3.0
# 강도 발생                               6.0
# 강도 검거                               5.0
# 강간 발생                             115.0
# 강간 검거                              98.0
# 절도 발생                            1070.0
# 절도 검거                             413.0
# 폭력 발생                            1278.0
# 폭력 검거                            1070.0
# total                            4061.0
# occurs_total                     2472.0
# arrest_total                     1589.0
# police_name                     서울종로경찰서
# address         대한민국 서울특별시 종로구 인사동5길 41
# lat                           37.571824
# lng                          126.984153
# gu                                  종로구
# Name: 1, dtype: object
# ===
# 2
# 살인 발생                              1.0
# 살인 검거                              0.0
# 강도 발생                              6.0
# 강도 검거                              4.0
# 강간 발생                             65.0
# 강간 검거                             46.0
# 절도 발생                           1153.0
# 절도 검거                            382.0
# 폭력 발생                            869.0
# 폭력 검거                            794.0
# total                           3320.0
# occurs_total                    2094.0
# arrest_total                    1226.0
# police_name                   서울남대문경찰서
# address         대한민국 서울특별시 중구 한강대로 410
# lat                          37.554758
# lng                         126.973498
# gu                                  중구
# Name: 2, dtype: object
# ===

# %%
for i, j in crime_police_outer[:3].iterrows():
    print(i)
    print(j["lat"])
    print("===")
# Out:
# 0
# 37.56361709999999
# ===
# 1
# 37.571824
# ===
# 2
# 37.5547584
# ===

# %%
crime_police_outer
# Out:
#     살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검
# 19              대한민국 서울특별시 강동구 성내로 57  37.528511  127.126822   강동구
# 20            대한민국 서울특별시 성북구 화랑로7길 32  37.603989  127.039937   성북구
# 21  대한민국 서울특별시 구로구 새말로 97 신도림테크노마트 5층  37.507442  126.890224   구로구
# 22            대한민국 서울특별시 서초구 반포대로 179  37.495468  127.005340   서초구
# 23             대한민국 서울특별시 양천구 목동동로 99  37.516771  126.865700   양천구
# 24             대한민국 서울특별시 송파구 중대로 221  37.501904  127.127134   송파구
# 25                   대한민국 서울특별시 노원경찰서  37.641836  127.072198   노원구
# 26            대한민국 서울특별시 서초구 동작대로 204  37.494596  126.983128   서초구
# 27             대한민국 서울특별시 도봉구 노해로 403  37.653359  127.052682   도봉구
# 28             대한민국 서울특별시 강남구 개포로 617  37.493490  127.077212   강남구
# 29          대한민국 서울특별시 금천구 시흥대로73길 50  37.456813  126.896806   금천구
# 30             대한민국 서울특별시 은평구 연서로 365  37.628020  126.928790   은평구

# %%
## iterrows()를 이용하여 31개 경찰서의 Marker를 표시하고, arrest_total을 반영한 Circle을 그리시오

map = folium.Map(location=[37.58, 127.0], zoom_start=11)

for i, j in crime_police_outer.iterrows():
    lat = j["lat"]
    lng = j["lng"]
    police_name = j["police_name"]
    arrest_total = j["arrest_total"]

    folium.Marker(location = [lat, lng],
                  icon=folium.Icon(color='red', icon='home'),
                  popup=police_name).add_to(map)

    folium.Circle(location = [lat, lng],
                  radius = arrest_total/2,
                  fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f7f182b232b32418a52f50f1a6ddc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f7f182b232b32418a52f50f1a6ddc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f7f182b232b32418a52f50f1a6ddc3 = L.map(
#                 &quot;map_29f7f182b232b32418a52f50f1a6ddc3&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_971e7a1b74f92196ef3d34e34a8974b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_971e7a1b74f92196ef3d34e34a8974b7.addTo(map_29f7f182b232b32418a52f50f1a6ddc3);
#
#
#             var marker_ce684928b97189f41a6d7affb0acc197 = L.marker(
#                 [37.56361709999999, 126.9896517],
#                 {}
#             ).addTo(map_29f7f182b232b32418a52f50f1a6ddc3);
#
#
#             var icon_1bf931deac62850e775855ec213f0cef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ce684928b97189f41a6d7affb0acc197.setIcon(icon_1bf931deac62850e775855ec213f0cef);
#
#
#         var popup_5981a49d6ed2a1625668103d0bcf6aa8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b7a87d6fc740a1e37de2dc5bc3d9e4c = $(`&lt;div id=&quot;html_3b7a87d6fc740a1e37de2dc5bc3d9e4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울중부경찰서&lt;/div&gt;`)[0];
#                 popup_5981a49d6ed2a1625668103d0bcf6aa8.setContent(html_3b7a87d6fc740a1e37de2dc5bc3d9e4c);
#
#
#
#         marker_ce684928b97189f41a6d7affb0acc197.bindPopup(popup_5981a49d6ed2a1625668103d0bcf6aa8)
#         ;
#
#
#
#
#             var circle_b7456c2f545d01112520eeb759651696 = L.circle(
#                 [37.56361709999999, 126.9896517],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 858.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_29f7f182b232b32418a52f50f1a6ddc3);
#
#
#             var marker_c07f93bc7b7a655fdef53d80746b445d = L.marker(
#                 [37.571824, 126.9841533],
#                 {}
#             ).addTo(map_29f7f182b232b32418a52f50f1a6ddc3);
#
#
#             var icon_81f06cbf1b4b704f9bb2442e58197939 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c07f93bc7b7a655fdef53d80746b445d.setIcon(icon_81f06cbf1b4b704f9bb2442e58197939);
#
#
#         var popup_b6f39856c22e426ed0a4c21fc9cd94ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aebb490e9a94bbf35785e0f4f48a2e81 = $(`&lt;div id=&quot;html_aebb490e9a94bbf35785e0f4f48a2e81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울종로경찰서&lt;/div&gt;`)[0];
#                 popup_b6f39856c22e426ed0a4c21fc9cd94ee.setContent(html_aebb490e9a94bbf35785e0f4f48a2e81);
#
#
#
#         marker_c07f93bc7b7a655fdef53d80746b445d.bindPopup(popup_b6f39856c22e426ed0a4c21fc9cd94ee)
#         ;
#
#
#
#
#             var circle_6aece972cb90f9cadff47233ab01e3c0 = L.circle(
#                 [37.571824, 126.9841533],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 794.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_29f7f182b232b32418a52f50f1a6ddc3);
#
#
#             var marker_15a3cb85bfe96961ff8b26164e880559 = L.marker(
#                 [37.5547584, 126.9734981],
#                 {}
#             ).addTo(map_29f7f182b232b32418a52f50f1a6ddc3);
#
#
#             var icon_10a28b27eaa7c790ddbc616b2b7a1c4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;

# %% [markdown]
# # 과제
#
# 1. 강력범죄 검거 건수와 발생 건수의 비율을 계산하여 "arrest_occurs_ratio" 열을 추가하시오. 만약 `NaN`이 있다면 0으로 채우시오.
# 2. "arrest_occurs_ratio"가 가장 큰 경찰서를 찾으시오.
# 3. "arrest_occurs_ratio"가 가장 작은 경찰서를 찾으시오.(단, 0은 제외한다.)
# 4. crime_police_outer에서 구의 개수를 세시오.
# 5. 구별로 "occurs_total"과 "arrest_total"를 groupby를 이용하여 계산하시오.
# 6. "금천구"의 "occurs_total"과 "arrest_total"를 평균으로 채우시오.
# 7. "seoul_geo.json"을 이용하여 구별로 "arrest_total"을 반영한 Choropleth을 그리시오.

# %% [markdown]
# 1. 강력범죄 검거 건수와 발생 건수의 비율을 계산하여 "arrest_occurs_ratio" 열을 추가하시오.

# %%
crime_police_outer["arrest_occurs_ratio"] = (crime_police_outer["arrest_total"]/
                                             crime_police_outer["occurs_total"]).fillna(0.0)

# %%
crime_police_outer
# Out:
#     살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거   절도 발생   절도 검거   폭력 발생   폭력 검거  \
# 0     2.0    2.0    3.0    2.0  105.0   65.0  1395.0   477.0  1355.0  1170.0
# 1     3.0    3.0    6.0    5.0  115.0   98.0  1070.0   413.0  1278.0  1070.0
# 2     1.0    0.0    6.0    4.0   65.0   46.0  1153.0   382.0   869.0   794.0
# 3     2.0    2.0    5.0    4.0  154.0  124.0  1812.0   738.0  2056.0  1711.0
# 4     3.0    2.0    5.0    4.0   96.0   63.0  1114.0   424.0  1015.0   861.0
# 5     5.0    5.0   14.0   14.0  194.0  173.0  1557.0   587.0  2050.0  1704.0
# 6     2.0    2.0    2.0    1.0   86.0   71.0   953.0   409.0  1194.0  1015.0
# 26            대한민국 서울특별시 서초구 동작대로 204  37.494596  126.983128   서초구
# 27             대한민국 서울특별시 도봉구 노해로 403  37.653359  127.052682   도봉구
# 28             대한민국 서울특별시 강남구 개포로 617  37.493490  127.077212   강남구
# 29          대한민국 서울특별시 금천구 시흥대로73길 50  37.456813  126.896806   금천구
# 30             대한민국 서울특별시 은평구 연서로 365  37.628020  126.928790   은평구
#
#     arrest_occurs_ratio
# 0              0.600000
# 1              0.642799
# 2              0.585482
# 3              0.640109
# 4              0.606359
# 5              0.650000
# 6              0.669647
# 7              0.679025
# 8              0.614452
# 9              0.604922
# 10             0.632222
# 11             0.588365
# 12             0.627348
# 13             0.668106
# 14             0.731266
# 15             0.655690
# 16             0.648826
# 17             0.585028
# 18             0.750224
# 19             0.604691
# 20             0.642149
# 21             0.620262
# 22             0.648817
# 23             0.621687
# 24             0.606816
# 25             0.637037
# 26             0.583664
# 27             0.713213
# 28             0.690038
# 29             0.000000
# 30             0.000000

# %% [markdown]
# 2. "arrest_occurs_ratio"가 가장 큰 경찰서를 찾으시오.

# %%
ratio_max = crime_police_outer["arrest_occurs_ratio"].max()

# %%
crime_police_outer[crime_police_outer["arrest_occurs_ratio"] 
                   == ratio_max]
# Out:
#     살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거   절도 발생   절도 검거   폭력 발생   폭력 검거  \
# 18    7.0    8.0   13.0   13.0  262.0  191.0  2096.0  1260.0  3207.0  2718.0
#
#      total  occurs_total  arrest_total police_name                 address  \
# 18  9775.0        5585.0        4190.0     서울강서경찰서  대한민국 서울특별시 강서구 화곡로 308
#
#           lat        lng   gu  arrest_occurs_ratio
# 18  37.551362  126.85028  강서구             0.750224

# %% [markdown]
# 3. "arrest_occurs_ratio"가 가장 작은 경찰서를 찾으시오.(단, 0은 제외한다.)

# %%
ratio_min = crime_police_outer[crime_police_outer["arrest_occurs_ratio"] != 0]["arrest_occurs_ratio"].min()
ratio_min
# Out:
# 0.5836637589214909

# %%
crime_police_outer[crime_police_outer["arrest_occurs_ratio"] == ratio_min]
# Out:
#     살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 26    1.0    2.0    1.0    1.0   59.0   56.0  653.0  186.0  547.0  491.0
#
#      total  occurs_total  arrest_total police_name                  address  \
# 26  1997.0        1261.0         736.0     서울방배경찰서  대한민국 서울특별시 서초구 동작대로 204
#
#           lat         lng   gu  arrest_occurs_ratio
# 26  37.494596  126.983128  서초구             0.583664

# %% [markdown]
# 4. crime_police_outer에서 구의 개수를 세시오.

# %%
crime_police_outer["gu"].unique()
# Out:
# array(['중구', '종로구', '서대문구', '용산구', '성북구', '동대문구', '마포구', '영등포구', '성동구',
#        '동작구', '광진구', '은평구', '강북구', '중랑구', '강남구', '관악구', '강서구', '강동구',
#        '구로구', '서초구', '양천구', '송파구', '노원구', '도봉구', '금천구'], dtype=object)

# %%
len(crime_police_outer["gu"].unique())
# Out:
# 25

# %%
crime_police_outer["gu"].value_counts()
# Out:
# 중구      2
# 강남구     2
# 성북구     2
# 서초구     2
# 은평구     2
# 종로구     2
# 도봉구     1
# 노원구     1
# 송파구     1
# 양천구     1
# 구로구     1
# 강동구     1
# 강서구     1
# 관악구     1
# 강북구     1
# 중랑구     1
# 광진구     1
# 동작구     1
# 성동구     1
# 영등포구    1
# 마포구     1
# 동대문구    1
# 용산구     1
# 서대문구    1
# 금천구     1
# Name: gu, dtype: int64

# %%
print("서울시 경찰서 수: ", len(crime_police_outer))
print("서울시 구의 수: ", len(crime_police_outer["gu"].unique()))
# Out:
# 서울시 경찰서 수:  31
# 서울시 구의 수:  25

# %% [markdown]
# 5. 구별로 "occurs_total"과 "arrest_total"를 groupby를 이용하여 계산하시오.

# %%
df_groupby = crime_police_outer[["gu", "occurs_total", "arrest_total"]].groupby(["gu"]).agg("sum")

# %%
df_groupby
# Out:
#       occurs_total  arrest_total
# gu
# 강남구         8617.0        5732.0
# 강동구         5244.0        3171.0
# 강북구         4257.0        3113.0
# 강서구         5585.0        4190.0
# 관악구         6345.0        3712.0
# 광진구         5909.0        3707.0
# 구로구         5646.0        3502.0
# 금천구            0.0           0.0
# 노원구         5130.0        3268.0
# 도봉구         2664.0        1900.0
# 동대문구        4720.0        3205.0
# 동작구         4074.0        2397.0
# 마포구         5854.0        3597.0
# 서대문구        4029.0        2579.0
# 서초구         5444.0        3450.0
# 성동구         3358.0        2123.0
# 성북구         4154.0        2729.0
# 송파구         6778.0        4113.0
# 양천구         4528.0        2815.0
# 영등포구        6867.0        4154.0
# 용산구         3820.0        2483.0
# 은평구         2085.0        1393.0
# 종로구         4705.0        2943.0
# 중구          4954.0        2942.0
# 중랑구         5193.0        3405.0

# %% [markdown]
# 6. "금천구"의 "occurs_total"과 "arrest_total"를 평균으로 채우시오.

# %%
df_groupby.loc["금천구"] = [df_groupby["occurs_total"].mean(), 
                            df_groupby["arrest_total"].mean()]

# %%
df_groupby
# Out:
#       occurs_total  arrest_total
# gu
# 강남구         8617.0       5732.00
# 강동구         5244.0       3171.00
# 강북구         4257.0       3113.00
# 강서구         5585.0       4190.00
# 관악구         6345.0       3712.00
# 광진구         5909.0       3707.00
# 구로구         5646.0       3502.00
# 금천구         4798.4       3064.92
# 노원구         5130.0       3268.00
# 도봉구         2664.0       1900.00
# 동대문구        4720.0       3205.00
# 동작구         4074.0       2397.00
# 마포구         5854.0       3597.00
# 서대문구        4029.0       2579.00
# 서초구         5444.0       3450.00
# 성동구         3358.0       2123.00
# 성북구         4154.0       2729.00
# 송파구         6778.0       4113.00
# 양천구         4528.0       2815.00
# 영등포구        6867.0       4154.00
# 용산구         3820.0       2483.00
# 은평구         2085.0       1393.00
# 종로구         4705.0       2943.00
# 중구          4954.0       2942.00
# 중랑구         5193.0       3405.00

# %% [markdown]
# 7. "seoul_geo.json"을 이용하여 구별로 "arrest_total"을 반영한 Choropleth을 그리시오.

# %%
seoul_geo_path = "../data/seoul_geo.json"
seoul_geo_str = json.load(open(seoul_geo_path, encoding='utf-8'))

# %%
seoul_geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127
gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02547266349976, 37.568943552237734],
#       [127.01070894177482, 37.54118048964762],
#       [126.98752996903328, 37.55094818807139],
#       [126.96448570553055, 37.548705692021635],
#       [126.96358226710812, 37.55605635475154],
#       [126.96873633279075, 37.56313604690827],
#       [127.02547266349976, 37.568943552237734]]]}},
#   {'type': 'Feature',
#    'id': '종로구',
#    'properties': {'code': '11010',
#     'name': '종로구',
#     'name_eng': 'Jongno-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9738864128702, 37.62949634786888],
#       [126.977175406416, 37.62859715400388],
#       [126.98879865992384, 37.6118927319756],
#       [126.99348293358314, 37.588565457216156],
#       [127.02527254528003, 37.57524616245249],
#       [127.02547266349976, 37.568943552237734],
#       [126.96873633279075, 37.56313604690827],
#       [126.95565425846463, 37.576080790881456],
#       [126.9524752030572, 37.60508692737045],
#       [126.95427017006129, 37.622033431339425],
#       [126.9738864128702, 37.62949634786888]]]}}]}

# %%
map = folium.Map(location=[37.58, 127.0], zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f90d7d8c29b7060f6d1be9a1c719996a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f90d7d8c29b7060f6d1be9a1c719996a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f90d7d8c29b7060f6d1be9a1c719996a = L.map(
#                 &quot;map_f90d7d8c29b7060f6d1be9a1c719996a&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5db6c947cd6df64ede290a67732abc2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b5db6c947cd6df64ede290a67732abc2.addTo(map_f90d7d8c29b7060f6d1be9a1c719996a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Choropleth(geo_data = seoul_geo_str, 
               data = df_groupby["arrest_total"],
               fill_color = "PuRd",
               key_on = "feature.id",
               legend_name = "서울 강력 범죄 검거 건수").add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f90d7d8c29b7060f6d1be9a1c719996a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f90d7d8c29b7060f6d1be9a1c719996a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f90d7d8c29b7060f6d1be9a1c719996a = L.map(
#                 &quot;map_f90d7d8c29b7060f6d1be9a1c719996a&quot;,
#                 {
#                     center: [37.58, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5db6c947cd6df64ede290a67732abc2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b5db6c947cd6df64ede290a67732abc2.addTo(map_f90d7d8c29b7060f6d1be9a1c719996a);
#
#
#             tile_layer_b5db6c947cd6df64ede290a67732abc2.addTo(map_f90d7d8c29b7060f6d1be9a1c719996a);
#
#
#             var choropleth_e6c869a0d3965caade020ee69e2d53c4 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_f6c4a41dc444ebd2db4b653aa7b42953_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f6c4a41dc444ebd2db4b653aa7b42953_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f6c4a41dc444ebd2db4b653aa7b42953 = L.geoJson(null, {
#                 onEachFeature: geo_json_f6c4a41dc444ebd2db4b653aa7b42953_onEachFeature,
#
#                 style: geo_json_f6c4a41dc444ebd2db4b653aa7b42953_styler,
#         });
#
#         function geo_json_f6c4a41dc444ebd2db4b653aa7b42953_add (data) {
#             geo_json_f6c4a41dc444ebd2db4b653aa7b42953
#                 .addData(data);
#         }
#             geo_json_f6c4a41dc444ebd2db4b653aa7b42953_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445],
