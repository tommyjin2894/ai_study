# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('ml_10_medicalalert_train.csv')
final_test = pd.read_csv('ml_10_medicalalert_test.csv')

# %%
train_df[train_df['patientid'] == 'patientid']
# Out:
#        patientid  timestamp  gender  age  di  copd  chf  ht  afib  w  pw  bps  \
# 21722  patientid  timestamp  gender  age  di  copd  chf  ht  afib  w  pw  bps
#
#        bpd  spo2  hr  gl  alert
# 21722  bpd  spo2  hr  gl  alert

# %%
train_df = train_df.iloc[train_df['alert'].dropna().index]

# %%
train_df.drop(index=21722, inplace=True)
train_df
# Out:
#                 patientid            timestamp gender age di copd chf ht afib  \
# 0      454198825010375512   2015-09-25 1:18:09      F  74  0    0   0  1    1
# 1      304887778694000807  2015-07-15 10:52:53      F  82  1    1   0  0    1
# 2      719782720396991269  2015-11-15 15:08:40      M  76  1    0   0  1    1
# 3       25450399443627950  2015-11-11 19:36:39      F  77  0    1   1  1    0
# 4      534906646683042373  2015-06-15 13:07:23      F  74  1    0   0  1    1
# ...                   ...                  ...    ...  .. ..  ...  .. ..  ...
# 24995  740754555106398996  2015-09-18 19:16:03      M  90  0    0   1  1    0
# 24996  183438107768703223  2015-07-11 19:44:06      F  73  1    0   1  1    1
# 24997  234531520285098844  2015-07-11 17:35:22      M  63  1    0   1  1    0
# 24998  848277834632648446  2015-10-10 17:37:23      M  66  1    0   0  1    1
# 24999  591418343084645314  2015-07-20 19:12:39      F  49  1    0   1  1    0
#
#                  w           pw  bps  bpd         spo2   hr   gl alert
# 0       88.9947504   89.0854688  145   72           92   79  NaN    No
# 1        77.564232    77.564232  128   70           95   73  135    No
# 2      87.67933498  86.99894698  136   65           96   61  NaN    No
# 3      71.39537803  71.98504902  124   60           99  100  NaN    No
# 4        87.089664    87.089664  163   81           99   71  141    No
# ...            ...          ...  ...  ...          ...  ...  ...   ...
# 24995            0            0   95   55          NaN  NaN  NaN    No
# 24996            0            0  NaN  NaN  96.17666626   41  NaN    No
# 24997  133.0838928  132.5849416  160   93           99   86  188    No
# 24998   67.9027224    68.492392  149   90           96   67  NaN    No
# 24999            0            0  NaN  NaN          NaN  NaN  245    No
#
# [24997 rows x 17 columns]

# %%
train_df.dtypes
# Out:
# patientid    object
# timestamp    object
# gender       object
# age          object
# di           object
# copd         object
# chf          object
# ht           object
# afib         object
# w            object
# pw           object
# bps          object
# bpd          object
# spo2         object
# hr           object
# gl           object
# alert        object
# dtype: object

# %%
final_test.dtypes
# Out:
# id             int64
# patientid      int64
# timestamp     object
# gender        object
# age            int64
# di           float64
# copd           int64
# chf          float64
# ht             int64
# afib           int64
# w            float64
# pw           float64
# bps          float64
# bpd          float64
# spo2         float64
# hr           float64
# gl           float64
# dtype: object

# %%
# NaN 값을 기본적으로 처리
train_df['patientid'] = train_df['patientid'].fillna(-1).astype('int64')  # 예: -1로 대체
train_df['timestamp'] = pd.to_datetime(train_df['timestamp'])
train_df['gender']    = train_df['gender'].astype('category')
train_df['age']       = train_df['age'].fillna(0).astype(int)
train_df['di']        = train_df['di'].fillna(0).astype(int)
train_df['copd']      = train_df['copd'].fillna(0).astype(int)
train_df['chf']       = train_df['chf'].fillna(0).astype(int)
train_df['ht']        = train_df['ht'].fillna(0).astype(int)
train_df['afib']      = train_df['afib'].fillna(0).astype(int)
train_df['w']         = train_df['w'].fillna(0.0).astype(float)
train_df['pw']        = train_df['pw'].fillna(0.0).astype(float)
train_df['bps']       = train_df['bps'].fillna(0.0).astype(float)
train_df['bpd']       = train_df['bpd'].fillna(0).astype(int)
train_df['spo2']      = train_df['spo2'].fillna(0).astype(float)
train_df['hr']        = train_df['hr'].fillna(0).astype(int)
train_df['gl']        = train_df['gl'].fillna(0).astype(float)
train_df['alert']     = train_df['alert'].astype(object)
train_df.dtypes
# Out:
# patientid             int64
# timestamp    datetime64[ns]
# gender             category
# age                   int32
# di                    int32
# copd                  int32
# chf                   int32
# ht                    int32
# afib                  int32
# w                   float64
# pw                  float64
# bps                 float64
# bpd                   int32
# spo2                float64
# hr                    int32
# gl                  float64
# alert                object
# dtype: object

# %%
final_test['patientid'] = final_test['patientid'].fillna(-1).astype('int64')  # 예: -1로 대체
final_test['timestamp'] = pd.to_datetime(final_test['timestamp'])
final_test['gender']    = final_test['gender'].astype('category')
final_test['age']       = final_test['age'].fillna(0).astype(int)
final_test['di']        = final_test['di'].fillna(0).astype(int)
final_test['copd']      = final_test['copd'].fillna(0).astype(int)
final_test['chf']       = final_test['chf'].fillna(0).astype(int)
final_test['ht']        = final_test['ht'].fillna(0).astype(int)
final_test['afib']      = final_test['afib'].fillna(0).astype(int)
final_test['w']         = final_test['w'].fillna(0.0).astype(float)
final_test['pw']        = final_test['pw'].fillna(0.0).astype(float)
final_test['bps']       = final_test['bps'].fillna(0.0).astype(float)
final_test['bpd']       = final_test['bpd'].fillna(0).astype(int)
final_test['spo2']      = final_test['spo2'].fillna(0).astype(float)
final_test['hr']        = final_test['hr'].fillna(0).astype(int)
final_test['gl']        = final_test['gl'].fillna(0).astype(float)
final_test.dtypes
# Out:
# id                    int64
# patientid             int64
# timestamp    datetime64[ns]
# gender             category
# age                   int32
# di                    int32
# copd                  int32
# chf                   int32
# ht                    int32
# afib                  int32
# w                   float64
# pw                  float64
# bps                 float64
# bpd                   int32
# spo2                float64
# hr                    int32
# gl                  float64
# dtype: object

# %%
train_df.isna().sum() / len(train_df)
# Out:
# patientid    0.0
# timestamp    0.0
# gender       0.0
# age          0.0
# di           0.0
# copd         0.0
# chf          0.0
# ht           0.0
# afib         0.0
# w            0.0
# pw           0.0
# bps          0.0
# bpd          0.0
# spo2         0.0
# hr           0.0
# gl           0.0
# alert        0.0
# dtype: float64

# %%
final_test.isna().sum() / len(train_df)
# Out:
# id           0.0
# patientid    0.0
# timestamp    0.0
# gender       0.0
# age          0.0
# di           0.0
# copd         0.0
# chf          0.0
# ht           0.0
# afib         0.0
# w            0.0
# pw           0.0
# bps          0.0
# bpd          0.0
# spo2         0.0
# hr           0.0
# gl           0.0
# dtype: float64

# %% [markdown]
# ### 체크리스트
# ```py
# - #id        :
# - #patientid :  환자id
# - #timestamp :  측정 시간
# - #gender    :  성
# - #age       :  나이
# - #di        :  당뇨
# - #copd      :  만성 폐질환
# - #chf       :  심부전증
# - #ht        :  고혈압
# - #afib      :  심박세동
# - #w         :  몸무게
# - #pw        :  가장 최근 측정 된 무게 (위의 몸무게와 합칠 필요성)
# - #bps       :  수축기 혈압
# - #bpd       :  이완기 혈압
# - #spo2      :  혈중 산소 포화도
# - #hr        :  맥박
# - #gl        :  혈당 (na 값이 많으므로 상관관계도를 그려보고 빼자)
# - #alerat    :  경고! 여부
# ```

# %% [markdown]
# ### 기본적으로 젠더, 경고 여부 원핫 인코딩

# %%
train_df = train_df[(train_df['gender'] == "F") | (train_df['gender'] ==  "M")]
final_test = final_test[(final_test['gender'] == "F") | (final_test['gender'] ==  "M")]

# %%
is_male = pd.get_dummies(train_df['gender'], drop_first=True)
train_df = train_df.drop(columns=['gender'])
train_df['is_male'] = is_male

# %%
is_male = pd.get_dummies(final_test['gender'], drop_first=True)
final_test = final_test.drop(columns=['gender'])
final_test['is_male'] = is_male

# %%
alert = pd.get_dummies(train_df['alert'], drop_first=True)
train_df = train_df.drop(columns=['alert'])
train_df['alert'] = alert

# %%
train_df.head()
# Out:
#             patientid           timestamp  age  di  copd  chf  ht  afib  \
# 0  454198825010375512 2015-09-25 01:18:09   74   0     0    0   1     1
# 1  304887778694000807 2015-07-15 10:52:53   82   1     1    0   0     1
# 2  719782720396991269 2015-11-15 15:08:40   76   1     0    0   1     1
# 3   25450399443627950 2015-11-11 19:36:39   77   0     1    1   1     0
# 4  534906646683042373 2015-06-15 13:07:23   74   1     0    0   1     1
#
#            w         pw    bps  bpd  spo2   hr     gl  is_male  alert
# 0  88.994750  89.085469  145.0   72  92.0   79    0.0    False  False
# 1  77.564232  77.564232  128.0   70  95.0   73  135.0    False  False
# 2  87.679335  86.998947  136.0   65  96.0   61    0.0     True  False
# 3  71.395378  71.985049  124.0   60  99.0  100    0.0    False  False
# 4  87.089664  87.089664  163.0   81  99.0   71  141.0    False  False

# %%
final_test.head()
# Out:
#    id            patientid           timestamp  age  di  copd  chf  ht  afib  \
# 0   1   986452681195952909 2015-07-28 16:56:36   75   1     0    0   1     1
# 1   2   279227943463908135 2015-07-19 18:04:45   60   1     1    0   1     1
# 2   3   190474597341608800 2015-08-11 00:10:17   76   0     0    0   0     0
# 3   4  1059985795439793914 2015-07-05 12:42:54   79   1     0    1   1     0
# 4   5   533141523892671381 2015-07-02 16:05:42   80   1     0    0   1     1
#
#             w          pw    bps  bpd  spo2  hr     gl  is_male
# 0   62.595696   62.595696  108.0   75  97.0  85  208.0    False
# 1  104.779752  104.280801  176.0   99  96.0  81    0.0    False
# 2  110.676448  107.954896  139.0   85   0.0  91    0.0     True
# 3  103.917930  102.511792  114.0   46  92.0  77   84.0     True
# 4   55.519661   55.701098  111.0   57  95.0  71  124.0     True

# %%
# 각 환자별 경고 여부 확인
for i in range(len(train_df['patientid'].unique())):
    how_many_alert = sum(train_df[train_df['patientid'] == train_df['patientid'].unique()[i]]['alert'] == True)
    if how_many_alert >= 4:
        print(train_df['patientid'].unique()[i],how_many_alert)
# Out:
# 444001157068914229 4
# 528664997917893845 7
# 212852248224364359 5
# 547677147397514433 4
# 1046573729552376237 7
# 964277668736257948 9
# 849621472243856125 4
# 870443832704584243 9
# 974342916543888846 5
# 134301308729958327 14
# 492079408014694146 5
# 391717411247049153 4
# 865871568061288978 6
# 979423219393107757 4

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats("png2x") # svg, retina, png2x ...
mpl.style.use("seaborn-v0_8")
mpl.rcParams.update({"figure.constrained_layout.use": True})
sns.set_context("paper") 
sns.set_palette("Set2") 
sns.set_style("whitegrid") 

plt.rc("font", family = "Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ### 히트맵을 확인하여 상관관계 파악

# %%
fig, ax = plt.subplots(figsize=(8,7))
sns.heatmap(train_df.drop(columns=['timestamp']).corr(),
            cmap='coolwarm',
            vmax=1,
            vmin=-1,
            ax=ax);

# %% [markdown]
# ### 몸무게 합치기
# - 최근 무게가 있으면 그것을 이용하고 없으면 이전 무게로 둘다 비어있으면 없애기

# %%
train_df = train_df[(train_df['pw'] != 0) | (train_df['w'] != 0)]
train_df.loc[train_df['pw'] == 0,'pw'] = train_df.loc[train_df['pw'] == 0,'w']

# %%
sns.barplot(data=train_df,
               x = 'age',
               y = 'pw',)
# Out:
# <Axes: xlabel='age', ylabel='pw'>

# %%
final_test.loc[final_test['pw'] == 0,'pw'] = train_df['pw'].mean()

# %%
train_df.drop(columns=['w'],inplace=True)
final_test.drop(columns=['w'],inplace=True)

# %% [markdown]
# ### 혈당지수 column 드랍 처리
# - 너무 많으므로

# %%
train_df.drop(columns=['gl'], inplace=True)
final_test.drop(columns=['gl'], inplace=True)

# %%
train_df.columns
# Out:
# Index(['patientid', 'timestamp', 'age', 'di', 'copd', 'chf', 'ht', 'afib',
#        'pw', 'bps', 'bpd', 'spo2', 'hr', 'is_male', 'alert'],
#       dtype='object')

# %%
# 환자 정보 이상과 나이와의 관계 확인해보기
fig, ax = plt.subplots(2, 3, figsize=(12, 8))
ax = ax.flatten()
for i in range(3, 8):
    sns.violinplot(data=train_df,
                   x=train_df.columns[i],
                   y='age',
                   split=True,
                   hue='alert',
                   ax=ax[i-3])
plt.tight_layout()
plt.show();
# Out:
# C:\Users\crazy\AppData\Local\Temp\ipykernel_1088\3518573804.py:11: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ### 정상 범위가 아닌 혈업 및 산소 포화도 확인

# %%
sns.violinplot(train_df[['bps', 'bpd', 'spo2']])
# Out:
# <Axes: >

# %%
# 0 인 값은 이상치... 각 이상치의 갯수 확인
all_0_weirdo = (train_df['bps'] == 0)
# 수치 3 값이 모두 이상한 0 값 drop 시키자!

train_df = train_df.drop(train_df[all_0_weirdo].index)

train_df[train_df['bps'] == 0]
# spo2 처리

# ... 음...꽤 많으니 이상치 평균으로 처리하자 
print(len(train_df[train_df['spo2'] == 0]))

# 나이대별 평균으로 채우기
print('나이대별 혈중 산소 포화도')
for i in range(5,11):
    ages = (train_df['age'] < i*10) & (train_df['age'] > (i-1)*10)
    spo2_is_zero = train_df['spo2'] == 0
    print(train_df[ages]['spo2'].mean())
    train_df.loc[ages & spo2_is_zero, 'spo2'] = train_df[ages]['spo2'].mean()
# Out:
# 1753
# 나이대별 혈중 산소 포화도
# 96.51525423728813
# 93.40537745604964
# 86.92536516818409
# 89.56906551495234
# 86.37168403512617
# 94.85840011950421

# %%
final_test

# 0 인 값은 이상치... 각 이상치의 갯수 확인
all_0_weirdo = (final_test['bps'] == 0)
# 수치 3 값이 모두 이상한 0 값 drop 시키자!

# final_test = final_test.drop(final_test[all_0_weirdo].index)
# spo2 처리

# ... 음...꽤 많으니 이상치 평균으로 처리하자 
print(len(final_test[final_test['spo2'] == 0]))

# 나이대별 평균으로 채우기
print('나이대별 혈중 산소 포화도')
for i in range(5,11):
    ages_fin = (final_test['age'] < i*10) & (final_test['age'] > (i-1)*10)
    spo2_is_zero = final_test['spo2'] == 0
    # 여기에서 평균은 테스트 데이터에서 가져와야 함
    print(train_df[ages]['spo2'].mean())
    final_test.loc[ages_fin & spo2_is_zero, 'spo2'] = train_df[ages]['spo2'].mean()
# Out:
# 1301
# 나이대별 혈중 산소 포화도
# 96.65950898253277
# 96.65950898253277
# 96.65950898253277
# 96.65950898253277
# 96.65950898253277
# 96.65950898253277

# %%
# 그래도 spo2 가 0 인 환자 제거
spo2_is_zero = train_df['spo2'] == 0
train_df = train_df.drop(index=train_df[spo2_is_zero].index)

# 테스트는 제거 X
spo2_is_zero = final_test['spo2'] == 0
final_test.loc[spo2_is_zero,'spo2'] = train_df['spo2'].mean()

# %%
sns.violinplot(train_df[['bps', 'bpd', 'spo2']])
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
x_train, x_test, y_train, y_test = train_test_split(train_df.iloc[:,2:-1],train_df.iloc[:,-1])

# %%
y_train.unique()
# Out:
# array([False,  True])

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
pred_ = model.predict(x_test)

print(classification_report(y_test,pred_))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.99      4932
#         True       0.04      0.05      0.04        60
#
#     accuracy                           0.97      4992
#    macro avg       0.51      0.52      0.51      4992
# weighted avg       0.98      0.97      0.97      4992

# %%
model_RF = RandomForestClassifier()
model_RF.fit(x_train,y_train)
pred_ = model_RF.predict(x_test)

print(classification_report(y_test,pred_))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      4932
#         True       0.00      0.00      0.00        60
#
#     accuracy                           0.99      4992
#    macro avg       0.49      0.50      0.50      4992
# weighted avg       0.98      0.99      0.98      4992
# c:\Users\crazy\.conda\envs\tensor-gpu\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\crazy\.conda\envs\tensor-gpu\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\crazy\.conda\envs\tensor-gpu\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
model_adb = AdaBoostClassifier()
model_adb.fit(x_train,y_train)
pred_ = model_adb.predict(x_test)

print(classification_report(y_test,pred_))
# Out:
# c:\Users\crazy\.conda\envs\tensor-gpu\lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      4932
#         True       0.00      0.00      0.00        60
#
#     accuracy                           0.99      4992
#    macro avg       0.49      0.50      0.50      4992
# weighted avg       0.98      0.99      0.98      4992

# %%
final_test[x_test.columns]
# Out:
#       age  di  copd  chf  ht  afib          pw    bps  bpd       spo2  hr  \
# 0      75   1     0    0   1     1   62.595696  108.0   75  97.000000  85
# 1      60   1     1    0   1     1  104.280801  176.0   99  96.000000  81
# 2      76   0     0    0   0     0  107.954896  139.0   85  96.659509  91
# 3      79   1     0    1   1     0  102.511792  114.0   46  92.000000  77
# 4      80   1     0    0   1     1   55.701098  111.0   57  95.000000  71
# ...   ...  ..   ...  ...  ..   ...         ...    ...  ...        ...  ..
# 7124   74   1     0    0   1     1   57.787621  126.0   63  98.000000  89
# 7125   65   1     0    1   1     1  123.830616  167.0  106  96.659509  70
# 7126   68   1     1    0   1     0   87.364930  146.0   65  90.366669  77
# 7127   61   1     0    0   1     0  108.408488  142.0   75  98.000000  78
# 7128   68   1     0    0   1     0   78.380698  174.0   90  99.000000  66
#
#       is_male
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
# ...       ...
# 7124    False
# 7125    False
# 7126    False
# 7127     True
# 7128    False
#
# [7129 rows x 12 columns]

# %%
# 정답지 형식 만들기

# 모델 별 예측 결과
pred1 = model.predict(final_test[x_test.columns])
# 1. DT
print(sum(pd.Series(pred1, name='alert')) / len(pred1))

pred2 = model_RF.predict(final_test[x_test.columns])
# 2. RF
print(sum(pd.Series(pred2, name='alert')) / len(pred2))

pred3 = model_adb.predict(final_test[x_test.columns])
# 3. adb
print(sum(pd.Series(pred3, name='alert')) / len(pred3))

# 머신러닝을 봤을떄 DT 가 좀더 테스트의 정답 라벨 비율(약1프로)과 비슷하므로 DT로 결정!

pd.DataFrame(np.array([pred1]).reshape(len(pred1)), index=range(0,len(pred1)), columns=['alert']).astype(int).to_csv('정답지.csv', index=False)
# Out:
# 0.055547762659559546
# 0.00042081638378454203
# 0.00014027212792818068

# %% [markdown]
# ### 딥러닝

# %%
import tensorflow as tf

# %%
final_test = final_test[x_train.columns]

# %%
x_train = x_train/x_train.max()
x_test = x_test/x_train.max()
final_test = final_test/x_train.max()

# %%
x_train_tensor = tf.convert_to_tensor(x_train, float)
x_test_tensor = tf.convert_to_tensor(x_test, float)
final_test_tensor = tf.convert_to_tensor(final_test, float)

# %%
y_test_tensor = tf.keras.utils.to_categorical(y_test)
y_train_tensor = tf.keras.utils.to_categorical(y_train)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, AUC
from tensorflow.keras.callbacks import EarlyStopping

inputs = keras.Input(shape=(12,))
dense = layers.Dense(128, activation='relu')(inputs)
dropout = layers.Dropout(0.25)(dense)
dense = layers.Dense(64, activation='relu')(dropout)
dropout = layers.Dropout(0.25)(dense)
dense = layers.Dense(32, activation='relu')(dropout)
dropout = layers.Dropout(0.25)(dense)
dense = layers.Dense(64, activation='relu')(dropout)
dropout = layers.Dropout(0.25)(dense)
dense = layers.Dense(128, activation='relu')(dropout)
output = layers.Dense(2, activation='softmax')(dense)

model_fnn = keras.Model(inputs=inputs, outputs=output, name='FNN')
model_fnn.summary()

model_fnn.compile(
    loss='categorical_crossentropy',
    optimizer=keras.optimizers.RMSprop(),
    metrics=[AUC()],
)
# Out:
# Model: "FNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 12)]              0
#
#  dense (Dense)               (None, 128)               1664
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 64)                2112
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 22,690
# Trainable params: 22,690
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_fnn.fit(x_train_tensor,y_train_tensor,
              validation_data=(x_test_tensor,y_test_tensor),
              batch_size=10000,epochs=200)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 2s 254ms/step - loss: 0.6832 - auc: 0.5604 - val_loss: 0.4407 - val_auc: 0.9880
# Epoch 2/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4309 - auc: 0.9894 - val_loss: 1.4988 - val_auc: 0.9880
# Epoch 3/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2043 - auc: 0.9893 - val_loss: 2.7504 - val_auc: 0.9880
# Epoch 4/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1100 - auc: 0.9884 - val_loss: 3.6831 - val_auc: 0.9880
# Epoch 5/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0836 - auc: 0.9886 - val_loss: 4.2914 - val_auc: 0.9880
# Epoch 6/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0765 - auc: 0.9885 - val_loss: 4.6520 - val_auc: 0.9880
# Epoch 7/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0755 - auc: 0.9881 - val_loss: 4.8905 - val_auc: 0.9880
# Epoch 8/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0729 - auc: 0.9887 - val_loss: 5.0683 - val_auc: 0.9880
# Epoch 9/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0703 - auc: 0.9896 - val_loss: 5.2146 - val_auc: 0.9880
# Epoch 10/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0711 - auc: 0.9888 - val_loss: 5.1094 - val_auc: 0.9880
# Epoch 11/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0714 - auc: 0.9890 - val_loss: 5.2057 - val_auc: 0.9880
# Epoch 12/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0702 - auc: 0.9890 - val_loss: 5.4513 - val_auc: 0.9880
# Epoch 13/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0694 - auc: 0.9895 - val_loss: 5.4117 - val_auc: 0.9880
# Epoch 14/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0683 - auc: 0.9893 - val_loss: 5.4957 - val_auc: 0.9880
# Epoch 15/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0672 - auc: 0.9895 - val_loss: 5.4216 - val_auc: 0.9880
# Epoch 16/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0680 - auc: 0.9890 - val_loss: 5.5008 - val_auc: 0.9880
# Epoch 17/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0671 - auc: 0.9896 - val_loss: 5.4915 - val_auc: 0.9880
# Epoch 18/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0676 - auc: 0.9891 - val_loss: 5.6475 - val_auc: 0.9880
# Epoch 19/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0675 - auc: 0.9892 - val_loss: 5.4433 - val_auc: 0.9880
# Epoch 124/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0605 - auc: 0.9916 - val_loss: 1.6506 - val_auc: 0.9880
# Epoch 125/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0611 - auc: 0.9911 - val_loss: 1.5706 - val_auc: 0.9880
# Epoch 126/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0613 - auc: 0.9911 - val_loss: 1.6645 - val_auc: 0.9880
# Epoch 127/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0603 - auc: 0.9913 - val_loss: 1.5758 - val_auc: 0.9880
# Epoch 128/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0618 - auc: 0.9910 - val_loss: 1.3393 - val_auc: 0.9880
# Epoch 129/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0622 - auc: 0.9916 - val_loss: 1.6251 - val_auc: 0.9880
# Epoch 130/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0612 - auc: 0.9908 - val_loss: 1.5145 - val_auc: 0.9880
# Epoch 131/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0607 - auc: 0.9913 - val_loss: 1.5442 - val_auc: 0.9880
# Epoch 132/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0602 - auc: 0.9917 - val_loss: 1.7060 - val_auc: 0.9880
# Epoch 133/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0596 - auc: 0.9923 - val_loss: 1.5945 - val_auc: 0.9880
# Epoch 134/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0596 - auc: 0.9919 - val_loss: 1.5262 - val_auc: 0.9880
# Epoch 135/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0604 - auc: 0.9917 - val_loss: 1.7025 - val_auc: 0.9880
# Epoch 136/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0621 - auc: 0.9908 - val_loss: 1.6932 - val_auc: 0.9880
# Epoch 137/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0612 - auc: 0.9909 - val_loss: 1.5783 - val_auc: 0.9880
# Epoch 138/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0607 - auc: 0.9913 - val_loss: 1.5146 - val_auc: 0.9880
# Epoch 139/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0600 - auc: 0.9919 - val_loss: 1.2927 - val_auc: 0.9880
# Epoch 140/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0601 - auc: 0.9919 - val_loss: 1.5059 - val_auc: 0.9880
# Epoch 141/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0596 - auc: 0.9921 - val_loss: 1.3230 - val_auc: 0.9880
# Epoch 142/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0609 - auc: 0.9914 - val_loss: 1.3140 - val_auc: 0.9880
# Epoch 143/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0599 - auc: 0.9919 - val_loss: 1.4056 - val_auc: 0.9880
# Epoch 144/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0603 - auc: 0.9912 - val_loss: 1.4467 - val_auc: 0.9880
# Epoch 145/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0598 - auc: 0.9919 - val_loss: 1.3022 - val_auc: 0.9880
# Epoch 146/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0605 - auc: 0.9915 - val_loss: 1.3767 - val_auc: 0.9880
# Epoch 147/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0597 - auc: 0.9919 - val_loss: 1.4977 - val_auc: 0.9880
# Epoch 148/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0598 - auc: 0.9920 - val_loss: 1.3281 - val_auc: 0.9880
# Epoch 149/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0599 - auc: 0.9918 - val_loss: 1.1896 - val_auc: 0.9880
# Epoch 150/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0607 - auc: 0.9916 - val_loss: 1.2379 - val_auc: 0.9880
# Epoch 151/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0603 - auc: 0.9914 - val_loss: 1.1542 - val_auc: 0.9880
# Epoch 152/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0603 - auc: 0.9917 - val_loss: 1.2451 - val_auc: 0.9880
# Epoch 153/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0593 - auc: 0.9920 - val_loss: 1.2178 - val_auc: 0.9880
# Epoch 154/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0599 - auc: 0.9921 - val_loss: 1.1288 - val_auc: 0.9880
# Epoch 155/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0602 - auc: 0.9915 - val_loss: 1.0042 - val_auc: 0.9880
# Epoch 156/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0612 - auc: 0.9915 - val_loss: 1.0472 - val_auc: 0.9880
# Epoch 157/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0601 - auc: 0.9920 - val_loss: 1.0901 - val_auc: 0.9880
# Epoch 158/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0591 - auc: 0.9925 - val_loss: 1.1097 - val_auc: 0.9880
# Epoch 159/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0596 - auc: 0.9920 - val_loss: 1.1154 - val_auc: 0.9880
# Epoch 160/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0602 - auc: 0.9917 - val_loss: 1.3939 - val_auc: 0.9880
# Epoch 161/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0629 - auc: 0.9906 - val_loss: 1.3063 - val_auc: 0.9880
# Epoch 162/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0607 - auc: 0.9917 - val_loss: 1.2042 - val_auc: 0.9880
# Epoch 163/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0600 - auc: 0.9919 - val_loss: 0.9638 - val_auc: 0.9880
# Epoch 164/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0611 - auc: 0.9914 - val_loss: 1.1423 - val_auc: 0.9880
# Epoch 165/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0593 - auc: 0.9922 - val_loss: 1.0924 - val_auc: 0.9880
# Epoch 166/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0593 - auc: 0.9922 - val_loss: 1.1329 - val_auc: 0.9880
# Epoch 167/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0598 - auc: 0.9919 - val_loss: 1.0723 - val_auc: 0.9880
# Epoch 168/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0601 - auc: 0.9918 - val_loss: 0.8686 - val_auc: 0.9880
# Epoch 169/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0609 - auc: 0.9918 - val_loss: 0.9759 - val_auc: 0.9880
# Epoch 170/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0595 - auc: 0.9924 - val_loss: 0.9700 - val_auc: 0.9880
# Epoch 171/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0599 - auc: 0.9918 - val_loss: 1.0444 - val_auc: 0.9880
# Epoch 172/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0601 - auc: 0.9916 - val_loss: 0.9785 - val_auc: 0.9880
# Epoch 173/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0596 - auc: 0.9921 - val_loss: 1.1448 - val_auc: 0.9880
# Epoch 174/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0602 - auc: 0.9915 - val_loss: 1.0739 - val_auc: 0.9880
# Epoch 175/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0593 - auc: 0.9921 - val_loss: 1.0468 - val_auc: 0.9880
# Epoch 176/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0595 - auc: 0.9920 - val_loss: 1.0597 - val_auc: 0.9880
# Epoch 177/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0604 - auc: 0.9914 - val_loss: 1.2002 - val_auc: 0.9880
# Epoch 178/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0612 - auc: 0.9915 - val_loss: 1.0802 - val_auc: 0.9880
# Epoch 179/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0591 - auc: 0.9924 - val_loss: 0.9285 - val_auc: 0.9880
# Epoch 180/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0592 - auc: 0.9925 - val_loss: 0.8742 - val_auc: 0.9880
# Epoch 181/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0600 - auc: 0.9919 - val_loss: 0.8784 - val_auc: 0.9880
# Epoch 182/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0593 - auc: 0.9924 - val_loss: 1.0394 - val_auc: 0.9880
# Epoch 183/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0586 - auc: 0.9926 - val_loss: 0.8427 - val_auc: 0.9880
# Epoch 184/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0590 - auc: 0.9927 - val_loss: 0.8647 - val_auc: 0.9880
# Epoch 185/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0596 - auc: 0.9921 - val_loss: 0.9189 - val_auc: 0.9880
# Epoch 186/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0598 - auc: 0.9921 - val_loss: 1.2499 - val_auc: 0.9880
# Epoch 187/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0622 - auc: 0.9912 - val_loss: 1.0463 - val_auc: 0.9880
# Epoch 188/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0604 - auc: 0.9914 - val_loss: 0.9777 - val_auc: 0.9880
# Epoch 189/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0592 - auc: 0.9925 - val_loss: 0.7652 - val_auc: 0.9880
# Epoch 190/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0606 - auc: 0.9918 - val_loss: 0.8900 - val_auc: 0.9880
# Epoch 191/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0593 - auc: 0.9922 - val_loss: 0.8819 - val_auc: 0.9880
# Epoch 192/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0592 - auc: 0.9923 - val_loss: 1.0583 - val_auc: 0.9880
# Epoch 193/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0608 - auc: 0.9915 - val_loss: 1.0487 - val_auc: 0.9880
# Epoch 194/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0592 - auc: 0.9921 - val_loss: 0.9254 - val_auc: 0.9880
# Epoch 195/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0592 - auc: 0.9922 - val_loss: 0.8227 - val_auc: 0.9880
# Epoch 196/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0586 - auc: 0.9926 - val_loss: 0.7827 - val_auc: 0.9880
# Epoch 197/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0596 - auc: 0.9919 - val_loss: 0.6653 - val_auc: 0.9880
# Epoch 198/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0600 - auc: 0.9925 - val_loss: 0.8522 - val_auc: 0.9880
# Epoch 199/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0597 - auc: 0.9921 - val_loss: 0.9533 - val_auc: 0.9880
# Epoch 200/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0600 - auc: 0.9920 - val_loss: 0.8870 - val_auc: 0.9880

# %% [markdown]
# ### AUC socores

# %%
from sklearn.metrics import roc_auc_score, auc, roc_curve

# %%
# 모델 1
y_scores = model.predict_proba(x_test)[:, 1]  # 양성 클래스의 확률
fpr, tpr, thresholds = roc_curve(y_test, y_scores)
dt_auc = auc(fpr, tpr)

# 모델 2
y_scores_RF = model_RF.predict_proba(x_test)[:, 1]  # 양성 클래스의 확률
fpr, tpr, thresholds = roc_curve(y_test, y_scores_RF)
rf_auc = auc(fpr, tpr)

# 모델 3
y_scores_adb = model_adb.predict_proba(x_test)[:, 1]  # 양성 클래스의 확률
fpr, tpr, thresholds = roc_curve(y_test, y_scores_adb)
adb_auc = auc(fpr, tpr)

# %%
print('DT의 auc',dt_auc)
print('RF의 auc',rf_auc)
print('ADBoost의 auc',adb_auc)
# Out:
# DT의 auc 0.5167883211678833
# RF의 auc 0.7051145579886455
# ADBoost의 auc 0.5912256690997566
