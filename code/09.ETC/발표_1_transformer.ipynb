# %% [markdown]
# # Transformer
#
# 1. seq2seq 문제 해결, 어떻게 ?
# 2. 순환하지 않고, 병렬 처리 가능
# 3. seq 길이가 길어질수록 나오는 문제 해결
# 4. 학습시간에 대한 문제
# 5. 시퀀스 길이가 문제 없고 병렬처리가 가능하게 됨
# 6. 지식
#     1. RNN : 시계열, 순차 데이터 예측 신경망 - 역전파시 기울기 소실 (과거데이터 소실) 문제
#     2. LSTM : input, forget, output, cell - 여전히 소실 문제가 난다. 여전히 순환 됨. 기울기 소실 문제 여전함
# 7. seq 2 seq
#     - 인코더 디코더, 내부는 순환 신경망
#     - 입력데이터의 정보가 소실되는 문제
# 8. 어텐션
#     - Q, K, V 쿼리, 키, 밸류
#     - 다양한 스코어 함수가 있다.
#
# 9. 트렌스 포머
#     ![image.png](attachment:image.png)
#     - 인코더 6개
#     - 디코더 6개

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 어텐션 시각화

# %% [markdown]
# ![image.png](attachment:image.png)
