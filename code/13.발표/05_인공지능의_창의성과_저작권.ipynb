# %% [markdown]
# ### 창의성
# - 새로운 개념, 기존의 개념을 조합해 새로 창작
#
# ### 논점
# - 독창성
# - 의도
# - 창작 과정
#
# ### 창의성 시험
# - 평균적인 인간수준은 넘음
# - 다수의 분야에 인간을 초월
# - 사람 최고수준은 넘지를 못함
# - 기계들과 비교할 때는 전부 비슷
#
# ### AI 드론
# case 1
# - 사람을 거역
# - 사령부 판단 무시
#
# case 2
# - 사람의 명령을 따름
# - 필요시 적 사살
#
# ### 저작권
# - 창작자의 권리 : 만든이의 권리를 보호
#
# 1. 소유 주체
# 2. 보호범위
# 3. Ai 가 학습한 배출한 저작권
#
# - 이미지 :
#     - 한번 촬영하면 영원히 재사용 가능
#     - 딥페이크 문제
# - 텍스트 : GPT 가 작성한 대본
#
# - OpenAI의 저작권 소송
#
#
#
#
#
#
#
# ### Nara AI Film
#
# Ai만으로 만든 영화 첫 저작권 인정

# %% [markdown]
# ### 결론
#
# AI 창의성 계속 논의중<br>
# AI 창의성은 인간의 평균을 상회<br>
# AI 가 생성한 작품에 대한 저작권과 소유권 문제는 중요<br>
# AI 좋은 사례도 있다.<br>
