# %% [markdown]
# ### 인공지능의 편향성과 차별문제
#
# 스테이블 디퓨전 : unprofessional worker : 흑인 고령의 남성을 보여줌
#
# 챗 GPT : 진보적
# LLAMA : 보수적
#
# ### 종류
# 1. 숨겨진 편향 : 고의적이지 않은 편향
# 2. 표본 편향 : 데이터의 편향성
# 3. 롱테일 편향 : 학습에서 특정 카테고리가 빠져있는 편향
# 4. 고의적 편향 : 해킹이나 공격을 통해 의도적으로 편향 - 가장 위험하다.
#
# ### 원인
# - 데이터 자체
# - 알고리즘
# - 출력 해석 방식
#
# ### Ai 차별
# - 개인특성 기반의 불공정한 대우
# - 편향이 차별로 이어지는 방법
#
# - MS : 테이 챗봇 사례
