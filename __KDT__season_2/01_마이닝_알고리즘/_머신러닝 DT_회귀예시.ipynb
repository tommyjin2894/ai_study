# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 데이터 파일 로드
data = pd.read_csv('/content/1.01.house.price.csv')

# 독립 변수와 종속 변수 설정
X = data[['size', 'year']]  # 아파트 크기와 연식
y = data['price']           # 아파트 가격

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# 결정 트리 회귀 모델 생성
tree_reg = DecisionTreeRegressor(max_depth=5, random_state=1)  # max_depth : 트리의 키

# 모델 학습
tree_reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=1)

# %%
# 테스트 데이터에 대한 예측 수행
y_pred = tree_reg.predict(X_test)

# 성능 지표 계산 및 출력
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)
print("Coefficient of Determination (R^2):", r2)
# Out:
# Mean Squared Error (MSE): 0.505
# Coefficient of Determination (R^2): -0.6694214876033056

# %%
# 시각화
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(tree_reg, filled=True, feature_names=['size', 'year'], rounded=True, fontsize=14)
plt.title('Decision Tree for Regression')
plt.show()

# Squared Error=(예측값−실제값)2

# %%
# 예측
import numpy as np

# 새로운 데이터 예시
new_data = np.array([[50, 10]])  # 120제곱미터 크기, 10년 연식

# 새로운 데이터에 대한 예측 수행
predicted_price = tree_reg.predict(new_data)
print(f"예측된 아파트 가격: {predicted_price[0]}")
# Out:
# 예측된 아파트 가격: 4.2
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
