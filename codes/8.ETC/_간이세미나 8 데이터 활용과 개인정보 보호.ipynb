# %% [markdown]
# # 데이터 활용과 개인정보 보호

# %% [markdown]
# # 빅데이터란
# - 방대한 모든 분석 또는 디지털화된 자료
#
# - 3v 양 종류 처리소도
# - 4v 정확성 가치
#
# - 요즘은 개인에 맞춘 데이터가 중요하다
#
# # 데이터 활용
#
#
# # 개인정보 보호
# - 데이터의 안전한 활용
#
# - 데이터 3법
#  - 개인 정보 보호법
#  - 정보 통신 망법
#  - 신용정보 법
#   국내법 : 균형
# - GDPR
#   유럽 법 : 좀더 엄격한
#
# 가명 처리 : 개인정보의 일부만 없앰
#   - 데이터 식별 및 분류
#   - 가명 처리 방법 선택 :
#     - 마스킹, 암호화, 대체, 샘플링, 범주화 등
#   - 가명 처리 수행
#   - 검증 및 테스트
#   - 가명 정보 관리
#
# 비식별화 기술 중요 : 안전하게 변환 및 개인정보 보호강화, 활용성 높힘
#
# 옵트 인
#   : 개인정보 보호 강화
#   - 사용자들이 명확히 동의한 경우만
#
#
# 옵트 아웃
#   : 체크박스가 디폴트로 설정이 되어있는것
#   - 간편하지만 직접 동의를 하지 않아도 암묵적으로 동의 되는것
#
# # 개인정보 보호 중심 설계 :
# - PDP : Private by Design
