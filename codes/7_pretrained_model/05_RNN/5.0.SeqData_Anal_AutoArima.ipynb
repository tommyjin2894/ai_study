# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp38-cp38-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (1.4.2)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima)
#   Downloading Cython-3.0.10-cp38-cp38-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (1.24.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (69.5.1)
# Requirement already satisfied: packaging>=17.1 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\crazy\.conda\envs\kdt\lib\site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp38-cp38-win_amd64.whl (615 kB)
#    ---------------------------------------- 0.0/615.5 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/615.5 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------- ----- 532.5/615.5 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 615.5/615.5 kB 6.5 MB/s eta 0:00:00
# Downloading Cython-3.0.10-cp38-cp38-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------- -------------------- 1.3/2.8 MB 28.1 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 35.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 25.5 MB/s eta 0:00:00
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.10 pmdarima-2.0.4

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# 데이터 로드
data = pd.read_csv('AirPassengers.csv', index_col='Month', parse_dates=True)

# %%
# 로그 변환
data_log = np.log(data)

# %%
# 데이터 분할
train_log = data_log[:'1959']
test_log = data_log['1960':]

# %%
# Auto-ARIMA 모델 학습
model_auto = auto_arima(train_log, seasonal=True, m=12)
model_auto_fit = model_auto.fit(train_log)

# %%
# 예측 수행
predictions_log = model_auto_fit.predict(n_periods=len(test_log))
predictions_log = pd.Series(predictions_log, index=test_log.index)

# %%
# 로그 변환 복원
predictions = np.exp(predictions_log)
test = np.exp(test_log)

# %%
# 성능 평가
mse = mean_squared_error(test, predictions)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 530.3513805657503

# %%
# 실제 값과 예측 값 시각화
plt.figure(figsize=(10, 6))
plt.plot(test, label='Actual')
plt.plot(predictions, label='Predicted', color='orange')
plt.title('ARIMA Model Forecast vs Actuals')
plt.legend()
plt.show()
