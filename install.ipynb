# %%
# !pip install nbformat
# !pip install numpy
# !pip install seaborn
# !pip install graphviz

# !pip install tensorflow[and-cuda]
# !pip install pydot
# !pip install scikit-learn

# !pip install xgboost
# !pip install pmdarima
# !pip install opencv-python
# !pip install matplotlib
# Out:
# Requirement already satisfied: nbformat in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.20.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: numpy in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: seaborn in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: graphviz in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (0.20.3)
# Requirement already satisfied: tensorflow[and-cuda] in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: packaging in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.32.3)
# Requirement already satisfied: setuptools in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (0.37.1)
# Collecting nvidia-cublas-cu12==12.5.3.2 (from tensorflow[and-cuda])
#   Using cached nvidia_cublas_cu12-12.5.3.2-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.5.82 (from tensorflow[and-cuda])
#   Using cached nvidia_cuda_cupti_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12==12.5.82 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (12.5.82)
# Collecting nvidia-cuda-nvrtc-cu12==12.5.82 (from tensorflow[and-cuda])
#   Using cached nvidia_cuda_nvrtc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.5.82 (from tensorflow[and-cuda])
#   Using cached nvidia_cuda_runtime_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==9.3.0.75 (from tensorflow[and-cuda])
#   Using cached nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.2.3.61 (from tensorflow[and-cuda])
#   Using cached nvidia_cufft_cu12-11.2.3.61-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.6.82 (from tensorflow[and-cuda])
#   Using cached nvidia_curand_cu12-10.3.6.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.3.83 (from tensorflow[and-cuda])
#   Using cached nvidia_cusolver_cu12-11.6.3.83-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.1.3 (from tensorflow[and-cuda])
#   Using cached nvidia_cusparse_cu12-12.5.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorflow[and-cuda]) (2.21.5)
# Collecting nvidia-nvjitlink-cu12==12.5.82 (from tensorflow[and-cuda])
#   Using cached nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow[and-cuda]) (0.44.0)
# Requirement already satisfied: rich in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow[and-cuda]) (13.9.4)
# Requirement already satisfied: namex in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow[and-cuda]) (0.0.8)
# Requirement already satisfied: optree in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow[and-cuda]) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow[and-cuda]) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow[and-cuda]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow[and-cuda]) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow[and-cuda]) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow[and-cuda]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow[and-cuda]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow[and-cuda]) (0.1.2)
# Using cached nvidia_cublas_cu12-12.5.3.2-py3-none-manylinux2014_x86_64.whl (363.3 MB)
# Using cached nvidia_cuda_cupti_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (24.9 MB)
# Using cached nvidia_cuda_runtime_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (895 kB)
# Using cached nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl (577.2 MB)
# Using cached nvidia_cufft_cu12-11.2.3.61-py3-none-manylinux2014_x86_64.whl (192.5 MB)
# Using cached nvidia_curand_cu12-10.3.6.82-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.3.83-py3-none-manylinux2014_x86_64.whl (130.3 MB)
# Using cached nvidia_cusparse_cu12-12.5.1.3-py3-none-manylinux2014_x86_64.whl (217.6 MB)
# Using cached nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.5.1 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.5.1 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.5.1 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.5.1 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.5.1 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.5.1 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.5.1 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.5.1 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.5.1 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.5.1 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.5.3.2 nvidia-cuda-cupti-cu12-12.5.82 nvidia-cuda-nvrtc-cu12-12.5.82 nvidia-cuda-runtime-cu12-12.5.82 nvidia-cudnn-cu12-9.3.0.75 nvidia-cufft-cu12-11.2.3.61 nvidia-curand-cu12-10.3.6.82 nvidia-cusolver-cu12-11.6.3.83 nvidia-cusparse-cu12-12.5.1.3 nvidia-nvjitlink-cu12-12.5.82
# Requirement already satisfied: pydot in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (3.0.2)
# Requirement already satisfied: pyparsing>=3.0.9 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pydot) (3.2.0)
# Requirement already satisfied: scikit-learn in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: xgboost in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: numpy in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from xgboost) (1.14.1)
# Requirement already satisfied: pmdarima in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: scikit-learn>=0.22 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (1.14.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (75.1.0)
# Requirement already satisfied: packaging>=17.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Requirement already satisfied: opencv-python in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: matplotlib in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /home/tommy/anaconda3/envs/p3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install torchvision
# !pip install torch
